# %% [markdown]
# ## High Level Computer Vision
# ### Exercise 2: Deep Neural Networks and Backpropagation

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
from resources.gradient_check import eval_numerical_gradient
from resources.data_utils import get_CIFAR10_data
from resources.vis_utils import visualize_grid
#from resources.solutions import *

# %% [markdown]
# Deep neural networks have shown staggering performances in various learning tasks, including computer vision, natural language processing, and sound processing. They have made the model design more flexible by enabling end-to-end training.
#
# In this exercise, we get to have a first hands-on experience with neural network training. Many frameworks (e.g., PyTorch, Tensorflow, Caffe) allow easy usage of deep neural networks without precise knowledge of the inner workings of backpropagation and gradient descent algorithms. While these are very useful tools, it is important to get a good understanding of how to implement basic network training from scratch before using these libraries to speed up the process. For this purpose, we will implement a simple two-layer neural network and its training algorithm based on back-propagation using only basic matrix operations in questions 1 to 3. In question 4, we will use a popular deep learning library, PyTorch, to do the same and understand the advantages offered by using such tools.
#
# As a benchmark to test our models, we consider an image classification task using the widely used CIFAR-10 dataset. This dataset consists of 50000 training images of 32x32 resolution with 10 object classes, namely airplanes, cars, birds, cats, deer, dogs, frogs, horses, ships, and trucks. The task is to code and train a parametrized model for classifying those images. This involves
#
# - Implementing the feedforward model (Question 1).
# - Implementing the backpropagation algorithm (gradient computation) (Question 2).
# - Training the model using stochastic gradient descent and improving the model training with better hyper-parameters (Question 3).
# - Using the PyTorch Library to implement the above and experiment with deeper networks (Question 4).
#
# A note on notation: Throughout the exercise, notation $v_i$ is used to denote the $i$-th element of vector $v$.

# %% [markdown]
# ### Question 1: Implementing the feedforward model (10 points)

# %% [markdown]
# In this question, we will implement a two-layered neural network architecture and the loss function to train it.

# %% [markdown]
# <img src="./resources/fig1.png" width="900" align=left>

# %% [markdown]
# **Model architecture.** Our architecture is shown in Fig.1. It has an input layer and two model layers – a hidden and an output layer. We start with randomly generated toy inputs of four dimensions and the number of classes K = 3 to build our model in Q1 and Q2, and in Q3 use images from the CIFAR-10 dataset to test our model on a real-world task. Hence input layer is 4-dimensional for now.
#
# In the hidden layer, there are ten units. The input layer and the hidden
# layer are connected via linear weighting matrix $W^{(1)}\in\mathbb{R}^{10\times
# 4}$ and the bias term $b^{(1)}\in\mathbb{R}^{10}$. The parameters $W^{(1)}$
# and $b^{(1)}$ are to be learnt later on. A linear operation is performed,
# $W^{(1)}x+b^{(1)}$, resulting in a 10 dimensional vector $z^{(2)}$. It is then
# followed by a relu non-linear activation $\phi$, applied element-wise on each
# unit, resulting in the activations $a^{(2)} = \phi(z^{(2)})$. Relu function has
# the following form:
# \begin{equation}
# \label{eq:sigmoid}
# \phi(u) =  \begin{cases}
#       u, & \text{if}\ u\geq0 \\
#       0, & \text{if}\ u <0
#     \end{cases}
# \end{equation}
#
# A similar linear operation is performed on $a^{(2)}$, resulting in $z^{(3)}=W^{(2)}a^{(2)}+b^{(2)}$, where $W^{(2)}\in\mathbb{R}^{3\times 10}$ and $b^{(2)}\in\mathbb{R}^{3}$; it is followed by the softmax activation to result in $a^{(3)}=\psi(z^{(3)})$. The softmax function is defined by:
# \begin{equation}
# \psi(u)_i =  \frac{\exp^{u_i}}{\sum_j{\exp^{u_j}}}
# \end{equation}
#
# The final functional form of our model is thus defined by
# \begin{align}
# \label{eq:feedforward-model-start}
# a^{(1)} & = x \\\
# z^{(2)} & = W^{(1)}a^{(1)}+b^{(1)} \\
# a^{(2)} & = \phi(z^{(2)}) \\
# z^{(3)} & = W^{(2)}a^{(2)}+b^{(2)} \\
# \label{eq:feedforward-model-end}
# f_\theta(x) := a^{(3)} & = \psi(z^{(3)}),
# \end{align}
# which takes a flattened 4 dimensional vector as input and outputs a $3$ dimensional vector, each entry in the output $f_k(x)$ representing the probability of image $x$ corresponding to the class $k$. We summarily indicate all the network parameters by $\theta=(W^{(1)},b^{(1)},W^{(2)},b^{(2)})$.

# %% [markdown]
# **Implementation.** We are now ready to implement the feedforward neural network.
#
# a) Implement the feedforward model. Verify that the scores you generate for the toy inputs match the correct scores. (5 points)

# %%
class TwoLayerNet(object):
    """
    A two-layer fully-connected neural network. The net has an input dimension of
    N, a hidden layer dimension of H, and performs classification over C classes.
    We train the network with a softmax loss function and L2 regularization on the
    weight matrices. The network uses a ReLU nonlinearity after the first fully
    connected layer.

    In other words, the network has the following architecture:

    input - fully connected layer - ReLU - fully connected layer - softmax

    The outputs of the second fully-connected layer are the scores for each class.
    """

    def __init__(self, input_size, hidden_size, output_size, std=1e-4):
        """
        Initialize the model. Weights are initialized to small random values and
        biases are initialized to zero. Weights and biases are stored in the
        variable self.params, which is a dictionary with the following keys:

        W1: First layer weights; has shape (D, H)
        b1: First layer biases; has shape (H,)
        W2: Second layer weights; has shape (H, C)
        b2: Second layer biases; has shape (C,)

        Inputs:
        - input_size: The dimension D of the input data.
        - hidden_size: The number of neurons H in the hidden layer.
        - output_size: The number of classes C.
        """
        self.params = {}
        self.params['W1'] = std * np.random.randn(input_size, hidden_size)
        self.params['b1'] = np.zeros(hidden_size)
        self.params['W2'] = std * np.random.randn(hidden_size, output_size)
        self.params['b2'] = np.zeros(output_size)
        
    def forward(self, X):
        """
        Compute the final outputs for a two layer fully connected neural
        network.

        Inputs:
        - X: Input data of shape (N, D). Each X[i] is a training sample.
        - y: Vector of training labels. y[i] is the label for X[i], and each y[i] is
          an integer in the range 0 <= y[i] < C. This parameter is optional; if it
          is not passed then we only return scores, and if it is passed then we
          instead return the loss and gradients.
        - reg: Regularization strength.

        Returns:
        A matrix scores of shape (N, C) where scores[i, c] is
        the score for class c on input X[i].
        """
        # Unpack variables from the params dictionary
        W1, b1 = self.params['W1'], self.params['b1']
        W2, b2 = self.params['W2'], self.params['b2']
        N, D = X.shape

        # Compute the forward pass
        scores = 0.
        #############################################################################
        # TODO: Perform the forward pass, computing the class probabilities for the #
        # input. Store the result in the scores variable, which should be an array  #
        # of shape (N, C).                                                          #
        #############################################################################
        # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
        
        
        #print(a1.shape, W1.shape, b1.shape, z2.shape, a2.shape, z3.shape, a3.shape)
        a1 = X
        z2= np.matmul(a1,W1) + b1
        a2 = relu(z2)
        z3 = np.matmul(a2,W2) + b2
        a3 = softmax(z3)
        scores = a3
        
        # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

        # If the targets are not given then jump out, we're done
        return scores 
    
def relu(U):
    return np.maximum(0,U)

def softmax(U):
    assert len(U.shape) == 2
    s = np.max(U, axis=1)
    s = s[:, np.newaxis]  # necessary step to do broadcasting
    expo = np.exp(U - s)
    div = np.sum(expo, axis=1)
    div = div[:, np.newaxis]
    return expo / div

# %%
# Create a small net and some toy data to check your implementations.
# Note that we set the random seed for repeatable experiments.

input_size = 4
hidden_size = 10
num_classes = 3
num_inputs = 5

def init_toy_model():
    np.random.seed(0)
    return TwoLayerNet(input_size, hidden_size, num_classes, std=1e-1)

def init_toy_data():
    np.random.seed(1)
    X = 10 * np.random.randn(num_inputs, input_size)
    y = np.array([0, 1, 2, 2, 1])
    return X, y

net = init_toy_model()
X, y = init_toy_data()

scores = net.forward(X)
print('Your scores:')
print(scores)
print()
print('Correct scores:')
correct_scores = np.asarray([
 [0.36446210, 0.22911264, 0.40642526],
 [0.47590629, 0.17217039, 0.35192332],
 [0.43035767, 0.26164229, 0.30800004],
 [0.41583127, 0.29832280, 0.28584593],
 [0.36328815, 0.32279939, 0.31391246]])
print(correct_scores)
print()

# The difference should be very small. We get < 1e-7
print('Difference between your scores and correct scores:')
print(np.sum(np.abs(scores - correct_scores)))

assert math.isclose(np.sum(np.abs(scores - correct_scores)), 0,  abs_tol=1e-6)
# Out:
# Your scores:
# [[0.3644621  0.22911264 0.40642526]
#  [0.47590629 0.17217039 0.35192332]
#  [0.43035767 0.26164229 0.30800004]
#  [0.41583127 0.2983228  0.28584593]
#  [0.36328815 0.32279939 0.31391246]]
#
# Correct scores:
# [[0.3644621  0.22911264 0.40642526]
#  [0.47590629 0.17217039 0.35192332]
#  [0.43035767 0.26164229 0.30800004]
#  [0.41583127 0.2983228  0.28584593]
#  [0.36328815 0.32279939 0.31391246]]
#
# Difference between your scores and correct scores:
# 2.9173411658645065e-08

# %% [markdown]
# b) We later guide the neural network parameters
# $\theta=(W^{(1)},b^{(1)},W^{(2)},b^{(2)})$ to fit the given data and label
# pairs. We do so by minimising the loss function. A popular choice of the loss
# function for training neural networks for multi-class classification is the
# cross-entropy loss. For a single input sample $x_i$, with label $y_i$, the loss
# function is defined as:
# \begin{align}
# J(\theta, x_i, y_i) &= -\log{P(Y=y_i,X=x_i)} \\
#                     &= -\log{f_\theta(x_i)_{y_i}} \\
#                     &= -\log{\psi(z^{(3)})_{y_i}} \\
# J(\theta, x_i, y_i) &= -\log\left[ \frac{\exp^{z^{(3)}_{y_i}}}{\sum^K_j{\exp^{z^{(3)}_j}}}\right]
# \label{eq:log-loss-softmax}
# \end{align}
#
# Averaging over the whole training set, we get
# \begin{equation}
# \label{eq:log-loss-softmax-empirical}
# J(\theta,\{x_i,y_i\}_{i=1}^{N}) = \frac{1}{N} \sum_{i=1}^N
# -log\left[ \frac{\exp^{z^{(3)}_{y_i}}}{\sum_j{\exp^{z^{(3)}_j}}}\right],
# \end{equation}
# where $K$ is the number of classes. Note that if the model has perfectly fitted
# to the data (\emph{i.e.} $f_\theta^k(x_i)=1$ whenever $x_i$ belongs to class $k$ and 0
# otherwise), then $J$ attains the minimum of $0$.
#
#
# Apart from trying to correctly predict the label, we have to prevent
# overfitting the model to the current training data.  This is done by encoding
# our prior belief that the correct model should be simple (Occam's razor); we
# add an $L_2$ regularisation term over the model parameters $\theta$.
# Specifically, the loss function is defined by:
# \begin{equation}
# \label{eq:log-loss-empirical-regularised}
# \tilde{J}(\theta) = \frac{1}{N} \sum_{i=1}^N
# -log\left[ \frac{\exp^{z^{(3)}_{y_i}}}{\sum_j{\exp^{z^{(3)}_j}}}\right]
# +\lambda \left(||W^{(1)}||_2^2 + ||W^{(2)}||_2^2 \right),
# \end{equation}
# where $||\cdot||_2^2$ is the squared $L_2$ norm. For example,
# \begin{equation}
# \label{eq:L2-term}
# ||W^{(1)}||_2^2 =
# \sum_{p=1}^{10} \sum_{q=1}^{4} W_{pq}^{(1)2}
# \end{equation}
# By changing the value of $\lambda$ it is possible to give weights to your prior belief on the degree of simplicity (regularity) of the true model.
#
# Implement the final loss function and let it return the loss value. Verify the code by
# running and matching the output cost $1.30378789133$. (5 points)

# %%
class TwoLayerNetv2(TwoLayerNet):
    def compute_loss(self, X, y=None, reg=0.0):
        """
        Compute the loss and gradients for a two layer fully connected neural
        network.

        Inputs:
        - X: Input data of shape (N, D). Each X[i] is a training sample.
        - y: Vector of training labels. y[i] is the label for X[i], and each y[i] is
          an integer in the range 0 <= y[i] < C. This parameter is optional; if it
          is not passed then we only return scores, and if it is passed then we
          instead return the loss and gradients.
        - reg: Regularization strength.

        Returns:
        - loss: Loss (data loss and regularization loss) for this batch of training
          samples.
        """
        # Unpack variables from the params dictionary
        W1, b1 = self.params['W1'], self.params['b1']
        W2, b2 = self.params['W2'], self.params['b2']
        N, D = X.shape

        # Compute the forward pass
        scores = 0.
        #############################################################################
        # TODO: Perform the forward pass, computing the class probabilities for the #
        # input. Store the result in the scores variable, which should be an array  #
        # of shape (N, C).                                                          #
        #############################################################################
        # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
        a1 = X
        z2= np.matmul(a1,W1) + b1
        a2 = relu(z2)
        z3 = np.matmul(a2,W2) + b2
        a3 = softmax(z3)
        scores = a3
        # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

        # If the targets are not given then jump out, we're done
        if y is None:
            return scores

        # Compute the loss
        loss = 0.
        #############################################################################
        # TODO: Finish the forward pass, and compute the loss. This should include  #
        # both the data loss and L2 regularization for W1 and W2. Store the result  #
        # in the variable loss, which should be a scalar. Use the Softmax           #
        # classifier loss.                                                          #
        #############################################################################
        # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
        data_loss = np.sum((-1)*np.log(scores[np.arange(len(scores)), y]))/N
        reg_loss = data_loss + reg * (np.linalg.norm(W1)**2 + np.linalg.norm(W2)**2 )
        loss = reg_loss
        # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
        return loss

# %%
# Compute loss in the same function
def init_toy_model_v2():
    np.random.seed(0)
    return TwoLayerNetv2(input_size, hidden_size, num_classes, std=1e-1)

net_v2 = init_toy_model_v2()
loss = net_v2.compute_loss(X, y, reg=0.05)
correct_loss = 1.30378789133

# should be very small, we get < 1e-12
print('Difference between your loss and correct loss:')
print(np.sum(np.abs(loss - correct_loss)))

assert math.isclose(np.sum(np.abs(loss - correct_loss)), 0,  abs_tol=1e-6)
# Out:
# Difference between your loss and correct loss:
# 1.7985612998927536e-13

# %% [markdown]
# ### Question 2: Backpropagation (15 points)

# %% [markdown]
# We train the model by solving
# \begin{equation}
# \label{eq:train-main}
# \underset{\theta}{\min} \,\,  \tilde{J}(\theta)
# \end{equation}
# via stochastic gradient descent. Therefore, We need an efficient computation of the gradients $\nabla_\theta \tilde{J}(\theta)$. We use backpropagation of top layer error signals to the parameters $\theta$ at different layers.
#
# In this question, you will be required to implement the backpropagation algorithm yourself from pseudocode. We will give a high-level description of what is happening in each line.
#
# For those who are interested in the robust derivation of the algorithm, we include the optional exercise on the derivation of the backpropagation algorithm. A piece of prior knowledge of standard vector calculus, including the chain rule, would be helpful.

# %% [markdown]
# **Backpropagation.** The backpropagation algorithm is simply a sequential application of the chain rule. It is applicable to any (sub-) differentiable model that is a composition of simple building blocks. In this exercise, we focus on the architecture with stacked layers of linear transformation + relu non-linear activation.
#
# The intuition behind the backpropagation algorithm is as follows. Given a training example $(x, y)$, we first run the feedforward to compute all the activations throughout the network, including the output value of the model $f_\theta(x)$ and the loss $J$. Then, for each parameter in the model, we want to compute the effect that parameter has on the loss. This is done by computing the derivatives of the loss w.r.t for each model parameter.
#
# The backpropagation algorithm is performed from the top of the network (loss layer) to the bottom. It sequentially computes the gradient of the loss function with respect to each layer's activations and parameters.
#
# Let’s start by deriving the gradients of the un-regularized loss function w.r.t final layer activations $z^{(3)}$. We will then use this in the chain rule to compute analytical expressions for gradients of all the model parameters.
#
# (a) Verify that the loss function (in Q1) has the gradient w.r.t $z^{(3)}$ as below.
# \begin{equation}
# \frac{\partial J}{\partial z^{(3)}}\left(\{x_i,y_i\}_{i=1}^{N}\right) = \frac{1}{N}\left(\psi(z^{(3)}) - \Delta\right),
# \end{equation}
# where $\Delta$ is a matrix of $N\times K$ dimensions with
# \begin{equation}
#         \Delta_{ij} = \begin{cases}
#         1, & \text{if}\ y_i =j \\
#                 0, & \text{otherwise}
# \end{cases}
# \end{equation}
# (please write your answer in the block below, 2 points)

# %% [markdown]
# \begin{align}
# J(\theta, x_i, y_i) &= -\log\left[ \frac{\exp^{z^{(3)}_{y_i}}}{\sum^K_j{\exp^{z^{(3)}_j}}}\right]
# \end{align}
# Averaging over entire dataset,
#
# \begin{align}
# J(\theta,\{x_i,y_i\}_{i=1}^{N}) = \frac{1}{N} \sum_{i=1}^N
# -log\left[ \frac{\exp^{z^{(3)}_{y_i}}}{\sum_j{\exp^{z^{(3)}_j}}}\right]
# \end{align}
# \begin{align}
# J(\theta,\{x_i,y_i\}_{i=1}^{N}) = \frac{1}{N} \sum_{i=1}^N
# -log[\psi(z^{(3)})_j]
# \end{align}
# psi function is softmax activation.
# $$ \psi(z^{(3)})_i = \frac{\exp^{z^{(3)}_{y_i}}}{\sum_j{\exp^{z^{(3)}_j}}}  $$
#
# Applying derivative,
# $$\frac{\partial J}{\partial z^{(3)}} {({x_i, y_i})_{i=1}^{N}} = \frac{\partial}{\partial z^{(3)}} \frac{1}{N}\sum_{i=1}^N -log[\psi(z^{(3)})_i] $$
#
# $$ = \frac{-1}{N} \sum_{1=1}^N \frac{\partial \psi(z^{(3)})_i}{\partial z^{(3)}}  $$
#
# let the above eqn be eqn(1)
#
# $$ \frac{\partial \psi(z^{(3)})_i}{\partial z^{(3)}}  = [\frac {\exp^{z^{(3)}}} {\sum_j{\exp^{z^{(3)}_j}}}] $$
#
# $$ = \frac {\exp^{z^{(3)}}.{\sum \exp^{z^{(3)}_{j}} - ({\exp^{z^{(3)}}})^2}} {[\sum_j{\exp^{z^{(3)}_j}}]^2}   $$
#
# $$ = \frac {\exp^{z^{(3)}}} {\sum_j{\exp^{z^{(3)}_j}}} . [1 - \frac {\exp^{z^{(3)}}} {\sum_j{\exp^{z^{(3)}_j}}}] $$
#
# $$ = \psi(z^{(3)})_i . [1 - \psi(z^{(3)})_i] $$
#
# let the above eqn be eqn (2)
#
# Substituting (2) in (1):
#
# $$ \frac{\partial J}{\partial z^{(3)}} =\frac{-1}{N} \sum_{1=1}^N \frac {1}{\psi(z^{(3)})_i} .  \psi(z^{(3)})_i . [1 - \psi(z^{(3)})_i] $$
#
# $$ = \frac {-1}{N} \sum_{1=1}^N [1 - \psi(z^{(3)})_i] $$
#
# $$ = \frac {1}{N} \sum_{1=1}^N [ \psi(z^{(3)})_i - 1] $$
#
# Therefore, $$ \frac{\partial J}{\partial z^{(3)}} = \frac {1}{N} \sum_{1=1}^N [ \psi(z^{(3)})_i - \Delta] $$
# where $\Delta$ is a matrix of $N\times K$ dimensions with
# \begin{equation}
#         \Delta_{ij} = \begin{cases}
#         1, & \text{if}\ y_i =j \\
#                 0, & \text{otherwise}
# \end{cases}
# \end{equation}

# %% [markdown]
# b) To compute the effect of the weight matrix $W^{(2)}$ on the loss (in Q1) incurred by the network, we compute the
# partial derivatives of the loss function with respect to $W^{2}$.  This is done
# by applying the chain rule. Verify that the partial derivative of the loss
# w.r.t $W^{(2)}$ is
# \begin{align}
# \label{eq:grad-loss-multi}
# \frac{\partial J}{\partial W^{(2)}}\left(\{x_i,y_i\}_{i=1}^{N}\right) &= \frac{\partial J}{\partial z^{(3)}} \cdot \frac{\partial z^{(3)}}{\partial W^{(2)}} \\
# &= \frac{1}{N} (\psi(z^{(3)}) - \Delta) a^{(2)'}
# \end{align}
#
# Similary, verify that the regularized loss has the derivatives
#
# \begin{equation}
# \frac{\partial \tilde{J}}{\partial W^{(2)}} = \frac{1}{N} (\psi(z^{(3)}) - \Delta) a^{(2)'} + 2\lambda W^{(2)}
# \end{equation}
#
# (please write your answer in the block below, 2 points)

# %% [markdown]
# $\frac{\delta J}{\delta W^{(2)}} (\{x_i, y_i\}_{i=1}^N) = \frac{\delta J}{\delta Z^{(3)}} [\frac{\delta Z^{(3)}}{\delta W^{(2)} }]$
#
# Substituting from before,
#
# $= \frac{1}{N} ( \psi (Z^{(3)})- \Delta) . \frac{\delta }{\delta W^{(2)}} [W^{(2)} a^{(2)} + b^{(2)}]$
#
# $ = \frac{1}{N} ( \psi (Z^{(3)})- \Delta) a^{(2)} $
#
# For regularized loss we have,
#
# $J(\theta) = \frac{1}{N} \sum^N_{i=1} - log[\frac{exp  ~Z^{(3)} y_i}{ \sum_j exp^2 ~j^{(3)}}] + \lambda (|| W^{(1)} ||^2_2 +|| W^{(2)} ||^2_2 )$
#
# $\frac{\delta J}{\delta W^{(2)}} = \frac{\delta J_1}{\delta W^{(2)}} + \frac{\delta J_2}{\delta W^{(2)}}$
#
# $=\frac{1}{N} ( \psi (Z^{(3)})- \Delta)  a^{(2)} +  \frac{\delta }{\delta W^{(2)}} [\lambda || W^{(1)} ||^2_2 +|| W^{(2)} ||^2_2 ]$
# $=\frac{1}{N} (\psi (Z^{(3)}) - \Delta) a^{(2)} + 2\lambda W^{(2)} $

# %% [markdown]
# c) We can repeatedly apply chain rule as discussed above to obtain the derivatives of the loss with respect to all the parameters of the model $\theta=(W^{(1)},b^{(1)},W^{(2)},b^{(2)})$.
# Dervive the expressions for the derivatives of the regularized loss (in Q1) w.r.t $W^{(1)}$, $b^{(1)}$, $b^{(2)}$ now.
# (please write your answer in the block below, 6 points)

# %% [markdown]
# $\frac{\delta J}{\delta b^{(2)}}= \frac{\delta J}{\delta z^{(3)}} [\frac{\delta z^{(3)}}{\delta b^{(2)} }]$\\
# =$\frac{1}{N}(\psi^3_2 - \delta).1$
#
#
#
# For regularized loss also, it is same (Since regularization term is independent of $b^2$)
#
#
#
# for non-regularized loss:
# $\frac{\delta J}{\delta W^{(1)}} = [\frac{\delta J}{\delta z^{(3)}}].[\frac{\delta z^{(3)}}{\delta a^{(2)} }].[\frac{\delta a^{(2)}}{\delta z^{(2)} }].[\frac{\delta z^{(2)}}{\delta W^{(1)} }]$
#
#
#
# where
# $ {a^{(2)}} = \phi (z^{(2)}) \\
# z^{(2)} = W^{(1)}a^{(1)} +b^{(1)} $
#
#
#
#
# = $\left\{
# \begin{array}{ c l }
# \frac{1}{N}(\psi(z^{(3)}) - \Delta).W^{(2)}.1.a^{(1)} & \quad \textrm{if } z^{(2)} \geq 0 \\
# 0 \quad & \textrm{otherwise}
# \end{array}
# \right.$
#
#
#
# For regularized loss: \\
# $\frac{\delta J}{\delta W^{(1)}} = [\frac{\delta J(non-reg)}{\delta W^{(1)}}]+\frac{\delta}{\delta W^1}.\lambda(||W^{(1)}||^2_2+||W^{(2)}||^2_2)$\\
#
#
#
# = $\left\{
# \begin{array}{ c l }
# 2\lambda W^{(1)} & \quad \textrm{if } z^{(2)} \leq 0 \\
# \frac{1}{N}.(\psi(z^{(3)} - \Delta).W^{(2)}.a^{(1)}+2\lambda W^{(1)} & \quad \textrm{otherwise}
# \end{array}
# \right.$
#
#
# $\frac{\delta J}{\delta b^{(1)}} = [\frac{\delta J}{\delta z^{(3)}}].[\frac{\delta z^{(3)}}{\delta a^{(2)} }].[\frac{\delta a^{(2)}}{\delta z^{(2)} }].[\frac{\delta z^{(2)}}{\delta b^{(1)} }]$
#
#
#
# = $\left\{
# \begin{array}{ c l }
# 0 & \quad \textrm{if } z^{(2)} \leq 0 \\
# \frac{1}{N}(\psi(z^{(3)}) - \Delta).W^{(2)}.1 & \quad \textrm{otherwise}
# \end{array}
# \right.$
#
#
#
# Since regularization term does not depend on $z^{(3)}$ it is same for regularization loss as well

# %% [markdown]
# d) Using the expressions you obtained for the derivatives of the loss w.r.t model
# parameters, implement the back-propagation algorithm. Run the code and verify that the
# gradients you obtained are correct using numerical gradients (already
# implemented in the code). The maximum relative error between the gradients you
# compute and the numerical gradients should be less than 1e-8 for all parameters.
# (5 points)

# %%
class TwoLayerNetv3(TwoLayerNetv2):
    def back_propagation(self, X, y=None, reg=0.0):
        """
        Compute the loss and gradients for a two layer fully connected neural
        network.

        Inputs:
        - X: Input data of shape (N, D). Each X[i] is a training sample.
        - y: Vector of training labels. y[i] is the label for X[i], and each y[i] is
          an integer in the range 0 <= y[i] < C. This parameter is optional; if it
          is not passed then we only return scores, and if it is passed then we
          instead return the loss and gradients.
        - reg: Regularization strength.

        Returns:
        - loss: Loss (data loss and regularization loss) for this batch of training
          samples.
        - grads: Dictionary mapping parameter names to gradients of those parameters
          with respect to the loss function; has the same keys as self.params.
        """
        # Unpack variables from the params dictionary
        W1, b1 = self.params['W1'], self.params['b1']
        W2, b2 = self.params['W2'], self.params['b2']
        N, D= X.shape


        # Compute the forward pass
        scores = 0.
        #############################################################################
        # TODO: Perform the forward pass, computing the class probabilities for the #
        # input. Store the result in the scores variable, which should be an array  #
        # of shape (N, C).                                                          #
        #############################################################################
        # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)****             
        a1 = X
        z2= np.matmul(a1,W1) + b1
        a2 = relu(z2)
        z3 = np.matmul(a2,W2) + b2
        a3 = softmax(z3)
        scores = a3
        # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

        # If the targets are not given then jump out, we're done
        if y is None:
            return scores

        # Compute the loss
        loss = 0.
        #############################################################################
        # TODO: Finish the forward pass, and compute the loss. This should include  #
        # both the data loss and L2 regularization for W1 and W2. Store the result  #
        # in the variable loss, which should be a scalar. Use the Softmax           #
        # classifier loss.                                                          #
        #############################################################################
        # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
        data_loss = np.sum((-1)*np.log(scores[np.arange(len(scores)), y]))/N
        reg_loss = data_loss + reg * (np.linalg.norm(W1)**2 + np.linalg.norm(W2)**2 )
        loss = reg_loss
        # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

        # Backward pass: compute gradients
        grads = {}
        #############################################################################
        # TODO: Compute the backward pass, computing the derivatives of the weights #
        # and biases. Store the results in the grads dictionary. For example,       #
        # grads['W1'] should store the gradient on W1, and be a matrix of same size #
        #############################################################################
        # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
        delta = np.zeros_like(scores)
        delta[np.arange(len(scores)), y] = 1
        grad_z3 = (1/N) * (scores - delta)        
        grads['W2'] = np.matmul(a2.T, grad_z3) + (2 * reg * W2)
        grads['b2'] = np.sum(grad_z3, axis=0)
        temp = np.matmul(grad_z3, W2.T)
        temp[z2 <= 0] = 0
        grads['W1'] = np.matmul(X.T, temp) + 2 * reg * W1
        grads['b1'] = np.sum(temp, axis=0)


        # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

        return loss, grads

# %%
# Compute the gradient
def init_toy_model_v3():
    np.random.seed(0)
    return TwoLayerNetv3(input_size, hidden_size, num_classes, std=1e-1)

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

net_v3 = init_toy_model_v3()

loss, grads = net_v3.back_propagation(X, y, reg=0.05)

# these should all be less than 1e-8 or so
for param_name in grads:
    f = lambda W: net_v3.back_propagation(X, y, reg=0.05)[0]
    param_grad_num = eval_numerical_gradient(f, net_v3.params[param_name], verbose=False)
    print('%s max relative error: %e' % (param_name, rel_error(param_grad_num, grads[param_name])))
# Out:
# W2 max relative error: 3.440708e-09
# b2 max relative error: 4.447646e-11
# W1 max relative error: 3.561318e-09
# b1 max relative error: 2.738421e-09

# %% [markdown]
# ### Question 3: Stochastic gradient descent training (10 points)

# %% [markdown]
# We have implemented the backpropagation algorithm for computing the parameter gradients and have verified that it indeed gives the correct gradient. We are now ready to train the network. We solve Eq.15 with the stochastic gradient descent.
#
# Typically neural networks are large and are trained with millions of data
# points. It is thus often infeasible to compute the gradient $\nabla_\theta
# \tilde{J}(\theta)$ that requires the accumulation of the gradient over the
# entire training set. Stochastic gradient descent addresses this problem by
# simply accumulating the gradient over a small random subset of the training
# samples (minibatch) at each iteration. Specifically, the algorithm is as
# follows,

# %% [markdown]
# <img src="./resources/alg1.png" width="900" align=left>

# %% [markdown]
# where the gradient $\nabla_\theta \tilde{J}(\theta,\{(X^\prime_j,y^\prime_j)\}_{j=1}^B)$ is computed only on the current randomly sampled batch.
#
# Intuitively, $v = -\nabla_\theta \tilde{J}(\theta^{(t-1)})$ gives the direction
# to which the loss $\tilde{J}$ decreases the most (locally), and therefore we
# follow that direction by updating the parameters towards that direction
# $\theta^{(t)} = \theta^{(t-1)} + v$.
#
# a) Implement the stochastic gradient descent algorithm and run the training on the toy data. Your model
# should be able to  obtain loss <= 0.02 on the training set and the training
# curve should look similar to the one shown in figure 2.

# %% [markdown]
# <img src="./resources/fig2.png" width="500" align=left>

# %%
class TwoLayerNetv4(TwoLayerNetv3):
    def train(self, X, y, X_val, y_val,
              learning_rate=1e-3, learning_rate_decay=0.95,
              reg=5e-6, num_iters=100,
              batch_size=200, verbose=False):
        """
        Train this neural network using stochastic gradient descent.

        Inputs:
        - X: A numpy array of shape (N, D) giving training data.
        - y: A numpy array f shape (N,) giving training labels; y[i] = c means that
          X[i] has label c, where 0 <= c < C.
        - X_val: A numpy array of shape (N_val, D) giving validation data.
        - y_val: A numpy array of shape (N_val,) giving validation labels.
        - learning_rate: Scalar giving learning rate for optimization.
        - learning_rate_decay: Scalar giving factor used to decay the learning rate
          after each epoch.
        - reg: Scalar giving regularization strength.
        - num_iters: Number of steps to take when optimizing.
        - batch_size: Number of training examples to use per step.
        - verbose: boolean; if true print progress during optimization.
        """
        num_train = X.shape[0]
        iterations_per_epoch = max(num_train / batch_size, 1)
        
        # Use SGD to optimize the parameters in self.model
        loss_history = []
        train_acc_history = []
        val_acc_history = []

        for it in range(num_iters):
            X_batch = X
            y_batch = y

            #########################################################################
            # TODO: Create a random minibatch of training data and labels, storing  #
            # them in X_batch and y_batch respectively.                             #
            #########################################################################
            # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
            random_idxs = np.random.choice(num_train, batch_size)
            X_batch = X[random_idxs]
            y_batch = y[random_idxs]
            # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

            # Compute loss and gradients using the current minibatch
            loss, grads = self.back_propagation(X_batch, y=y_batch, reg=reg)
            loss_history.append(loss)

            #########################################################################
            # TODO: Use the gradients in the grads dictionary to update the         #
            # parameters of the network (stored in the dictionary self.params)      #
            # using stochastic gradient descent. You'll need to use the gradients   #
            # stored in the grads dictionary defined above.                         #
            #########################################################################
            # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
            self.params['W2'] -= learning_rate * grads['W2']
            self.params['b2'] -= learning_rate * grads['b2']
            self.params['W1'] -= learning_rate * grads['W1']
            self.params['b1'] -= learning_rate * grads['b1']
            # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

            if verbose and it % 100 == 0:
                print('iteration %d / %d: loss %f' % (it, num_iters, loss))

            # Every epoch, check train and val accuracy and decay learning rate.
            if it % iterations_per_epoch == 0:
                # Check accuracy
                train_acc = (self.predict(X_batch) == y_batch).mean()
                val_acc = (self.predict(X_val) == y_val).mean()
                train_acc_history.append(train_acc)
                val_acc_history.append(val_acc)

                # Decay learning rate
                learning_rate *= learning_rate_decay

        return {
          'loss_history': loss_history,
          'train_acc_history': train_acc_history,
          'val_acc_history': val_acc_history,
        }
    
    def predict(self, X):
        """
        Use the trained weights of this two-layer network to predict labels for
        data points. For each data point we predict scores for each of the C
        classes, and assign each data point to the class with the highest score.

        Inputs:
        - X: A numpy array of shape (N, D) giving N D-dimensional data points to
          classify.

        Returns:
        - y_pred: A numpy array of shape (N,) giving predicted labels for each of
          the elements of X. For all i, y_pred[i] = c means that X[i] is predicted
          to have class c, where 0 <= c < C.
        """
        y_pred = None

        ###########################################################################
        # TODO: Implement this function; it should be VERY simple!                #
        ###########################################################################
        # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
        z = np.dot(X, self.params['W1']) + self.params['b1']
        h = np.maximum(z, 0)
        out = np.dot(h, self.params['W2']) + self.params['b2']
        y_pred = np.argmax(out, axis=1)
        # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

        return y_pred

# %%
def init_toy_model_v4():
    np.random.seed(0)
    return TwoLayerNetv4(input_size, hidden_size, num_classes, std=1e-1)

net_v4 = init_toy_model_v4()
stats = net_v4.train(X, y, X, y,
            learning_rate=1e-1, reg=5e-6,
            num_iters=100, verbose=False)

print('Final training loss: ', stats['loss_history'][-1])

# plot the loss history
plt.plot(stats['loss_history'])
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.show()
# Out:
# Final training loss:  0.017149607938732093

# %% [markdown]
# b) We are now ready to train our model on a real image dataset. For this, we will use
# the CIFAR-10 dataset.  Since the images are of size $32\times 32$ pixels with 3
# color channels, this gives us 3072 input layer units, represented by a vector
# $x\in\mathbb{R}^{3072}$. The code to load the data and train the model is provided with
# some default hyperparameters. With default
# hyperparameters, if previous questions have been done correctly, you should get
# a validation set accuracy of about 29\%. This is very poor.
# Your task is to debug the model training and come up with better hyperparameters
# to improve the performance on the validation set.
# Visualize the training and validation performance curves to help with this analysis.
# There are several pointers provided in the comments to
# help you understand why the network might be underperforming.
# Once you have tuned your hyperparameters, and get validation accuracy greater
# than 48\% run your best model on the test set once and report the performance.

# %% [markdown]
# **Download CIFAR-10 using this link: <http://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz>**
# <br />
# **Decompress the downloaded dataset, and put the `cifar-10-batches-py` folder in the foleder `datasets`**

# %%
def show_net_weights(net):
    W1 = net.params['W1']
    W1 = W1.reshape(32, 32, 3, -1).transpose(3, 0, 1, 2)
    plt.imshow(visualize_grid(W1, padding=3).astype('uint8'))
    plt.gca().axis('off')
    plt.show()

# # Load the data
# Now that you have implemented a two-layer network that passes
# gradient checks and works on toy data, it's time to load up our favorite
# CIFAR-10 data so we can use it to train a classifier on a real dataset.
# Invoke the get_CIFAR10_data function to get our data.

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)

# Visualize some images to get a feel for the data
plt.imshow(visualize_grid(X_train[:100, :].reshape(100, 32,32, 3), padding=3).astype('uint8'))
plt.gca().axis('off')
plt.show()

# # Train a network
# To train our network we will use SGD. In addition, we will
# adjust the learning rate with an exponential learning rate schedule as
# optimization proceeds; after each epoch, we will reduce the learning rate by
# multiplying it by a decay rate.

input_size = 32 * 32 * 3
hidden_size = 50
num_classes = 10
net = TwoLayerNetv4(input_size, hidden_size, num_classes)
# Train the network
stats = net.train(X_train, y_train, X_val, y_val,
            num_iters=1000, batch_size=200,
            learning_rate=1e-4, learning_rate_decay=0.95,
            reg=0.25, verbose=True)

# Predict on the validation set
val_acc = (net.predict(X_val) == y_val).mean()
print('Validation accuracy: ', val_acc)

# # Debug the training
# With the default parameters we provided above, you should get a validation
# accuracy of about 0.29 on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the loss
# function and the accuracies on the training and validation sets during
# optimization.
#
# Another strategy is to visualize the weights that were learned in the first
# layer of the network. In most neural networks trained on visual data, the
# first layer weights typically show some visible structure when visualized.

# Plot the loss function and train / validation accuracies
# plt.subplot(2, 1, 1)
plt.plot(stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')
# plt.savefig("3b_default_loss.png")
plt.show()

# plt.subplot(2, 1, 2)
plt.plot(stats['train_acc_history'], label='train')
plt.plot(stats['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Classification accuracy')
plt.legend()
# plt.savefig("3b_default_accuracy.png")
plt.show()

# # Visualize the weights of the network

show_net_weights(net)

# # Tune your hyperparameters
#
# **What's wrong?**. Looking at the visualizations above, we see that the loss
# is decreasing more or less linearly, which seems to suggest that the learning
# rate may be too low. Moreover, there is no gap between the training and
# validation accuracy, suggesting that the model we used has low capacity, and
# that we should increase its size. On the other hand, with a very large model
# we would expect to see more overfitting, which would manifest itself as a
# very large gap between the training and validation accuracy.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they
# affect the final performance is a large part of using Neural Networks, so we
# want you to get a lot of practice. Below, you should experiment with
# different values of the various hyperparameters, including hidden layer size,
# learning rate, numer of training epochs, and regularization strength. You
# might also consider tuning the learning rate decay, but you should be able to
# get good performance using the default value.
#
# **Approximate results**. You should be aim to achieve a classification
# accuracy of greater than 48% on the validation set. Our best network gets
# over 52% on the validation set.
#
# **Experiment**: You goal in this exercise is to get as good of a result on
# CIFAR-10 as you can (52% could serve as a reference), with a fully-connected
# Neural Network. Feel free implement your own techniques (e.g. PCA to reduce
# dimensionality, or adding dropout, or adding features to the solver, etc.).

# **Explain your hyperparameter tuning process in the report.**

best_net = None # store the best model into this

#################################################################################
# TODO: Tune hyperparameters using the validation set. Store your best trained  #
# model in best_net.                                                            #
#                                                                               #
# To help debug your network, it may help to use visualizations similar to the  #
# ones we used above; these visualizations will have significant qualitative    #
# differences from the ones we saw above for the poorly tuned network.          #
#                                                                               #
# Tweaking hyperparameters by hand can be fun, but you might find it useful to  #
# write code to sweep through possible combinations of hyperparameters          #
#################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

## Tested combinations
# learning_rates=[0.00001, 0.0001, 0.001, 0.01]
learning_rates=[0.001, 0.002, 0.003, 0.005]
regularization_strengths = [0.02,0.03, 0.05, 0.08]
batch_size= [32, 64, 128, 256, 512]
num_iters=[1000, 3000, 5000]
hidden_size=[300,400,500]

## Best model
learning_rates=[0.001]
regularization_strengths = [0.08]
batch_size=[256]
num_iters=[3000]
hidden_size=[500]

best_acc = -1
best_stats = None
best_params=[]
for hs in hidden_size:
    for ni in num_iters:
        for bs in batch_size:
            for lr in learning_rates:
                for rs in regularization_strengths:
                    net = TwoLayerNetv4(input_size, hs, num_classes)
                    stats = net.train(X_train, y_train, X_val, y_val,
                                num_iters=ni, batch_size=bs,
                                learning_rate=lr, learning_rate_decay=0.95,
                                reg=rs, verbose=False)

                    # Predict on the validation set
                    val_acc = (net.predict(X_val) == y_val).mean()
                    trn_acc = (net.predict(X_train) == y_train).mean()
                    if val_acc > best_acc:
                        best_acc=val_acc
                        best_net = net
                        best_stats = stats
                        print("Best accuracy: ")
                        print (best_acc)
                        best_params=[hs, ni, bs, lr, rs, trn_acc, val_acc]
                        print("\nHyperparameters of best model: ")
                        print(best_params)

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

# visualize the weights of the best network
stats = best_net.train(X_train, y_train, X_val, y_val,
            num_iters=best_params[1], batch_size=best_params[2],
            learning_rate=best_params[3], learning_rate_decay=0.90,
            reg=best_params[4], verbose=True)

# Predict on the validation set
val_acc = (best_net.predict(X_val) == y_val).mean()
print('Validation accuracy: ', val_acc)
show_net_weights(best_net)


# # Run on the test set
# When you are done experimenting, you should evaluate your final trained
# network on the test set; you should get above 48%.

test_acc = (best_net.predict(X_test) == y_test).mean()
print('Test accuracy: ', test_acc)
# Out:
# Train data shape:  (49000, 3072)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3072)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3072)
# Test labels shape:  (1000,)
# iteration 0 / 1000: loss 2.302967
# iteration 100 / 1000: loss 2.302563
# iteration 200 / 1000: loss 2.298655
# iteration 300 / 1000: loss 2.268700
# iteration 400 / 1000: loss 2.176040
# iteration 500 / 1000: loss 2.130244
# iteration 600 / 1000: loss 2.080840
# iteration 700 / 1000: loss 2.085438
# iteration 800 / 1000: loss 1.990216
# iteration 900 / 1000: loss 2.009263
# Validation accuracy:  0.28
# Best accuracy:
# 0.536
#
# Hyperparameters of best model:
# [500, 3000, 256, 0.001, 0.08, 0.6438367346938776, 0.536]
# iteration 0 / 3000: loss 1.188481
# iteration 100 / 3000: loss 1.153445
# iteration 200 / 3000: loss 1.168191
# iteration 300 / 3000: loss 1.352654
# iteration 400 / 3000: loss 1.207066
# iteration 500 / 3000: loss 1.094846
# iteration 600 / 3000: loss 1.072420
# iteration 700 / 3000: loss 0.972810
# iteration 800 / 3000: loss 1.096217
# iteration 900 / 3000: loss 1.118473
# iteration 1000 / 3000: loss 1.244714
# iteration 1100 / 3000: loss 1.053768
# iteration 1200 / 3000: loss 1.162963
# iteration 1300 / 3000: loss 1.196813
# iteration 1400 / 3000: loss 1.249123
# iteration 1500 / 3000: loss 0.977387
# iteration 1600 / 3000: loss 1.067359
# iteration 1700 / 3000: loss 1.171138
# iteration 1800 / 3000: loss 1.127922
# iteration 1900 / 3000: loss 1.128678
# iteration 2000 / 3000: loss 1.078847
# iteration 2100 / 3000: loss 1.175568
# iteration 2200 / 3000: loss 1.050932
# iteration 2300 / 3000: loss 0.966730
# iteration 2400 / 3000: loss 0.945623
# iteration 2500 / 3000: loss 0.970455
# iteration 2600 / 3000: loss 0.988522
# iteration 2700 / 3000: loss 0.924632
# iteration 2800 / 3000: loss 1.491017
# iteration 2900 / 3000: loss 0.994356
# Validation accuracy:  0.522
# Test accuracy:  0.512

# %% [markdown]
# ### Explanation of results
# In 3b,figure plotted for the model with given parameters shows that training accuracy is fluctuating a lot with the no of epochs. This shows that model is going through under fitting and over fitting repetitively and the accuracy growth is not steady even until 40th epoch. At epoch 20, the training accuracy is very high but validation accuracy is low, means that it is over-fitting on the training data therefore model is not preforming that good on unseen data (i.e. validation dataset), same is the case after 30 epoch.
#
# ### Fine tuning Hyperparameters
# Best model should have good validation accuracy other than training accuracy. For that, we have trained multiple models using different values of hyperparameters and picked the one that has shown the best validation accuracy. Fine-tuned hyperparameters along with their test values are as follows:
#
# * Testing Combination
#     * Learning rate [0.001, 0.002, 0.003, 0.005]
#     * Batch size 64, 128, 256, 512]
#     * Regularization strength [0.02, 0.03, 0.05, 0.08]
#     * Number of hidden units [300,400,500]
#     * Number of iterations [1000, 3000, 5000]
#
# ####  Best Model
# * Hyperparameters for best performed model
#     * Learning rate: 0.001
#     * Batch size: 256
#     * Regularization strength: 0.08
#     * Number of hidden units: 500
#     * Number of iterations: 3000
#
# <blockquote>
#     <p>Achieved Validation accuracy: 53.6% </p>
#     <p>Achieved Testing accuracy: 51.2% </p>
# </blockquote>
#
# ![alt-text-1](resources/bestloss.png "Loss") ![alt-text-2](resources/bestaccuracy.png "accuracy")

# %% [markdown]
# ### Question 4: Implement multi-layer perceptron using PyTorch library (10 points)

# %% [markdown]
# So far, we have implemented a two-layer network by explicitly writing down the expressions for the forward and backward computations and training algorithms using simple matrix multiplication primitives from the NumPy library.
#
# However there are many libraries available designed make experimenting with neural networks faster by abstracting away the details into re-usable modules. One such popular open-source library is PyTorch (https://pytorch.org/). In this final question we will use the PyTorch library to implement the same two-layer network we did before and train it on the Cifar-10 dataset. However, extending a two-layer network to a three or four layered one is a matter of changing two-three lines of code using PyTorch. We will take advantage of this to experiment with deeper networks to improve the performance on the CIFAR-10 classification.
#
# To install the pytorch library follow the instruction in
# https://pytorch.org/get-started/locally/ . If you have access to a Graphics Processing
# Unit (GPU), you can install the gpu verison and run the exercise on GPU for faster run
# times. If not, you can install the cpu version (select cuda version None) and run on the
# cpu. Having gpu access is not necessary to complete the exercise.  There are good tutorials
# for getting started with pytorch on their website (https://pytorch.org/tutorials/).
#
# a) Complete the code to implement a multi-layer perceptron network in the class
# `MultiLayerPerceptron`. This includes instantiating the
# required layers from `torch.nn` and writing the code for forward pass. Initially you
# should write the code for the same two-layer network we have seen before.
# (3 points)

# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
import sys

def weights_init(m):
    if type(m) == nn.Linear:
        m.weight.data.normal_(0.0, 1e-3)
        m.bias.data.fill_(0.)

def update_lr(optimizer, lr):
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

#--------------------------------
# Device configuration
#--------------------------------
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device: %s'%device)

#--------------------------------
# Hyper-parameters
#--------------------------------
input_size = 32 * 32 * 3
hidden_size = [50]
num_classes = 10
num_epochs = 20
batch_size = 200
learning_rate = 1e-3
learning_rate_decay = 0.95
reg=0.001
num_training= 49000
num_validation =1000
train = True

#-------------------------------------------------
# Load the CIFAR-10 dataset
#-------------------------------------------------
norm_transform = transforms.Compose([transforms.ToTensor(),
                                     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                                     ])
cifar_dataset = torchvision.datasets.CIFAR10(root='datasets/',
                                           train=True,
                                           transform=norm_transform,
                                           download=False)

test_dataset = torchvision.datasets.CIFAR10(root='datasets/',
                                          train=False,
                                          transform=norm_transform
                                          )
#-------------------------------------------------
# Prepare the training and validation splits
#-------------------------------------------------
mask = list(range(num_training))
train_dataset = torch.utils.data.Subset(cifar_dataset, mask)
mask = list(range(num_training, num_training + num_validation))
val_dataset = torch.utils.data.Subset(cifar_dataset, mask)

#-------------------------------------------------
# Data loader
#-------------------------------------------------
train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                           batch_size=batch_size,
                                           shuffle=True)

val_loader = torch.utils.data.DataLoader(dataset=val_dataset,
                                           batch_size=batch_size,
                                           shuffle=False)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                          batch_size=batch_size,
                                          shuffle=False)
# Out:
# Using device: cpu

# %%
#======================================================================================
# Q4: Implementing multi-layer perceptron in PyTorch
#======================================================================================
# So far we have implemented a two-layer network using numpy by explicitly
# writing down the forward computation and deriving and implementing the
# equations for backward computation. This process can be tedious to extend to
# large network architectures
#
# Popular deep-learining libraries like PyTorch and Tensorflow allow us to
# quickly implement complicated neural network architectures. They provide
# pre-defined layers which can be used as building blocks to define our
# network. They also enable automatic-differentiation, which allows us to
# define only the forward pass and let the libraries perform back-propagation
# using automatic differentiation.
#
# In this question we will implement a multi-layer perceptron using the PyTorch
# library.  Please complete the code for the MultiLayerPerceptron, training and
# evaluating the model. Once you can train the two layer model, experiment with
# adding more layers and
#--------------------------------------------------------------------------------------

#-------------------------------------------------
# Fully connected neural network with one hidden layer
#-------------------------------------------------
class MultiLayerPerceptron(nn.Module):
    def __init__(self, input_size, hidden_layers, num_classes):
        super(MultiLayerPerceptron, self).__init__()
        #################################################################################
        # TODO: Initialize the modules required to implement the mlp with given layer   #
        # configuration. input_size --> hidden_layers[0] --> hidden_layers[1] .... -->  #
        # hidden_layers[-1] --> num_classes                                             #
        # Make use of linear and relu layers from the torch.nn module                   #
        #################################################################################
        layers = []
        # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
        self.flatten = nn.Flatten()
        self.dropout = nn.Dropout(0.25)
        layers.append(nn.Linear(input_size,hidden_layers[0]))
        layers.append(nn.ReLU(layers))
        
        if len(hidden_layers)!=1:
            for i in range(1,len(hidden_layers)):
                layers.append(nn.Linear(hidden_layers[i-1],hidden_layers[i]))
                layers.append(nn.ReLU(layers))
        
        layers.append(nn.Linear(hidden_layers[-1],num_classes))
               
        #Reference: https://pytorch.org/tutorials/beginner/basics/buildmodel_tutorial.html
        # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
        self.layers = nn.Sequential(*layers)

    def forward(self, x):
        #################################################################################
        # TODO: Implement the forward pass computations                                 #
        # Note that you do not need to use the softmax operation at the end.            #
        # Softmax is only required for the loss computation and the criterion used below#
        # nn.CrossEntropyLoss() already integrates the softmax and the log loss together#
        #################################################################################
        # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
        x=self.flatten(x)
        if len(hidden_size)==(4 or 5):
            x = self.dropout(x)
        logits= self.layers(x)
        return logits
    
        #Reference: https://pytorch.org/tutorials/beginner/basics/buildmodel_tutorial.html
        # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****


model = MultiLayerPerceptron(input_size, hidden_size, num_classes).to(device)

# %% [markdown]
# b) Complete the code to train the network. Make use of the loss function `torch.nn.CrossEntropyLoss` to compute the loss and `loss.backward()` to compute the gradients. Once gradients are computed, `optimizer.step()` can be invoked to update the model. Your should be able to achieve similar performance ($>$ 48\% accuracy on the validation set) as in Q3. Report the final validation accuracy you achieve with a two-layer network. (3 points)

# %%
# Training
validation_accuracy=[]
for layers in range(0,5):
    model.apply(weights_init)

    # Loss and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=reg)

    # Train the model
    lr = learning_rate
    total_step = len(train_loader)
    if layers!=0:
        hidden_size.append(50)    
    for epoch in range(num_epochs):
        correct = 0
        total = 0 
        for i, (images, labels) in enumerate(train_loader):
            # if(i>2):
            #     break
            # Move tensors to the configured device
            images = images.to(device)
            labels = labels.to(device)
            #################################################################################
            # TODO: Implement the training code                                             #
            # 1. Pass the images to the model                                               #
            # 2. Compute the loss using the output and the labels.                          #
            # 3. Compute gradients and update the model using the optimizer                 #
            # Use examples in https://pytorch.org/tutorials/beginner/pytorch_with_examples.html
            #################################################################################
            # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

            prediction=model(images)
            loss=criterion(prediction,labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            predicted = prediction.argmax(1)

            #Reference:  https://pytorch.org/tutorials/beginner/basics/optimization_tutorial.html
            # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

            if (i+1) % 10 == 0:
                print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}'
                       .format(epoch+1, num_epochs, i+1, total_step, loss.item()))
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        print('Train accuracy is: {} %'.format(100 * correct / total))
        # Code to update the lr
        lr *= learning_rate_decay
        update_lr(optimizer, lr)
        with torch.no_grad():
            correct = 0
            total = 0
            for images, labels in val_loader:
                images = images.to(device)
                labels = labels.to(device)
                ####################################################
                # TODO: Implement the evaluation code              #
                # 1. Pass the images to the model                  #
                # 2. Get the most confident predicted class        #
                ####################################################
                # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
                #images = images.view(200, input_size)
                prediction = model.forward(images)
                predicted = prediction.argmax(1)
                # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
            print(len(hidden_size) +1,"Layer Network:")
            print('Validataion accuracy is: {} %'.format(100 * correct / total))
            if epoch==19:
                validation_accuracy.append((100 * correct / total))
                print("Final validation accuracy for different layers", validation_accuracy)
    
    # # Save the model checkpoint
    if layers==0:
        torch.save(model.state_dict(), 'model1.ckpt')
    elif layers==1:
        torch.save(model.state_dict(), 'model2.ckpt')
    elif layers==2:
        torch.save(model.state_dict(), 'model3.ckpt')
    elif layers==3:
        torch.save(model.state_dict(), 'model4.ckpt')
    elif layers==4:
        torch.save(model.state_dict(), 'model5.ckpt')
    elif layers==5:
        torch.save(model.state_dict(), 'model6.ckpt')

max_val_accuracy = max(validation_accuracy)


max_index = validation_accuracy.index(max_val_accuracy)

for j in range(0,len(hidden_size)):
    print("Final validation accuracy for ",j+2," layer network is: ",validation_accuracy[j])
print("Best model is:",max_index+2, "layer network")
    
if max_index==0:
    best_model = torch.load('model1.ckpt')
elif max_index==1:
    best_model = torch.load('model2.ckpt')
elif max_index==2:
    best_model = torch.load('model3.ckpt')
elif max_index==3:
    best_model = torch.load('model4.ckpt')
elif max_index==4:
    best_model = torch.load('model5.ckpt')
elif max_index==5:
    best_model = torch.load('model6.ckpt')
        
    

##################################################################################
# TODO: Now that you can train a simple two-layer MLP using above code, you can  #
# easily experiment with adding more layers and different layer configurations   #
# and let the pytorch library handle computing the gradients                     #
#                                                                                #
# Experiment with different number of layers (atleast from 2 to 5 layers) and    #
# record the final validation accuracies Report your observations on how adding  #
# more layers to the MLP affects its behavior. Try to improve the model          #
# configuration using the validation performance as the guidance. You can        #
# experiment with different activation layers available in torch.nn, adding      #
# dropout layers, if you are interested. Use the best model on the validation    #
# set, to evaluate the performance on the test set once and report it            #
##################################################################################
# Answer: The whole training and validating code (above) is run in a loop for different
# number of layers

# # Save the model checkpoint
# torch.save(model.state_dict(), 'model.ckpt')

# # Run the test code once you have your by setting train flag to false
# # and loading the best model

# # best_model = None # torch.load()
# best_model = torch.load('model.ckpt')
model.load_state_dict(best_model)
# Test the model
# In test phase, we don't need to compute gradients (for memory efficiency)
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)
        ####################################################
        # TODO: Implement the evaluation code              #
        # 1. Pass the images to the model                  #
        # 2. Get the most confident predicted class        #
        ####################################################
        # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
        prediction = model.forward(images)
        predicted = prediction.argmax(1)
        # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        if total == 1000:
            break

    print('Accuracy of the network on the {} test images: {} %'.format(total, 100 * correct / total))
# Out:
# Epoch [1/20], Step [10/245], Loss: 2.1869
# Epoch [1/20], Step [20/245], Loss: 2.0977
# Epoch [1/20], Step [30/245], Loss: 1.9828
# Epoch [1/20], Step [40/245], Loss: 1.8530
# Epoch [1/20], Step [50/245], Loss: 1.9015
# Epoch [1/20], Step [60/245], Loss: 1.9067
# Epoch [1/20], Step [70/245], Loss: 1.7586
# Epoch [1/20], Step [80/245], Loss: 1.7708
# Epoch [1/20], Step [90/245], Loss: 1.8436
# Epoch [1/20], Step [100/245], Loss: 1.7046
# Epoch [1/20], Step [110/245], Loss: 1.6692
# Epoch [1/20], Step [120/245], Loss: 1.6618
# Epoch [1/20], Step [130/245], Loss: 1.7031
# Epoch [1/20], Step [140/245], Loss: 1.6703
# Epoch [1/20], Step [150/245], Loss: 1.7412
# Epoch [1/20], Step [160/245], Loss: 1.7139
# Epoch [1/20], Step [170/245], Loss: 1.6543
# Epoch [1/20], Step [180/245], Loss: 1.6728
# Epoch [1/20], Step [190/245], Loss: 1.6721
# Epoch [1/20], Step [200/245], Loss: 1.5823
# Epoch [1/20], Step [210/245], Loss: 1.6187
# Epoch [1/20], Step [220/245], Loss: 1.7987
# Epoch [1/20], Step [230/245], Loss: 1.6295
# Epoch [1/20], Step [240/245], Loss: 1.6751
# Train accuracy is: 36.118367346938776 %
# 2 Layer Network:
# Validataion accuracy is: 42.4 %
# Epoch [2/20], Step [10/245], Loss: 1.4827
# Epoch [2/20], Step [20/245], Loss: 1.4981
# Epoch [2/20], Step [30/245], Loss: 1.5655
# Epoch [2/20], Step [40/245], Loss: 1.7353
# Epoch [2/20], Step [50/245], Loss: 1.5794
# Epoch [2/20], Step [60/245], Loss: 1.6143
# Epoch [2/20], Step [70/245], Loss: 1.5277
# Epoch [2/20], Step [80/245], Loss: 1.5938
# Epoch [2/20], Step [90/245], Loss: 1.6494
# Epoch [2/20], Step [100/245], Loss: 1.6923
# Epoch [2/20], Step [110/245], Loss: 1.5992
# Epoch [2/20], Step [120/245], Loss: 1.6698
# Epoch [2/20], Step [130/245], Loss: 1.5234
# Epoch [2/20], Step [140/245], Loss: 1.5433
# Epoch [2/20], Step [150/245], Loss: 1.5293
# Epoch [2/20], Step [160/245], Loss: 1.4880
# Epoch [2/20], Step [170/245], Loss: 1.5633
# Epoch [2/20], Step [180/245], Loss: 1.5049
# Epoch [2/20], Step [190/245], Loss: 1.5152
# Epoch [2/20], Step [200/245], Loss: 1.5383
# Epoch [2/20], Step [210/245], Loss: 1.5333
# Epoch [2/20], Step [220/245], Loss: 1.5895
# Epoch [2/20], Step [230/245], Loss: 1.6461
# Epoch [2/20], Step [240/245], Loss: 1.5390
# Train accuracy is: 44.31224489795918 %
# 2 Layer Network:
# Validataion accuracy is: 46.1 %
# Epoch [3/20], Step [10/245], Loss: 1.5412
# Epoch [3/20], Step [20/245], Loss: 1.5696
# Epoch [3/20], Step [30/245], Loss: 1.5685
# Epoch [3/20], Step [40/245], Loss: 1.4926
# Epoch [3/20], Step [50/245], Loss: 1.4483
# Epoch [3/20], Step [60/245], Loss: 1.4694
# Epoch [3/20], Step [70/245], Loss: 1.5538
# Epoch [3/20], Step [80/245], Loss: 1.4492
# Epoch [3/20], Step [90/245], Loss: 1.4640
# Epoch [3/20], Step [100/245], Loss: 1.5604
# Epoch [3/20], Step [110/245], Loss: 1.5228
# Epoch [3/20], Step [120/245], Loss: 1.5034
# Epoch [3/20], Step [130/245], Loss: 1.4408
# Epoch [3/20], Step [140/245], Loss: 1.5450
# Epoch [3/20], Step [150/245], Loss: 1.4601
# Epoch [3/20], Step [160/245], Loss: 1.5372
# Epoch [3/20], Step [170/245], Loss: 1.5300
# Epoch [3/20], Step [180/245], Loss: 1.3980
# Epoch [3/20], Step [190/245], Loss: 1.6772
# Epoch [3/20], Step [200/245], Loss: 1.5264
# Epoch [3/20], Step [210/245], Loss: 1.4542
# Epoch [3/20], Step [220/245], Loss: 1.4703
# Epoch [3/20], Step [230/245], Loss: 1.5518
# Epoch [3/20], Step [240/245], Loss: 1.5562
# Train accuracy is: 47.03469387755102 %
# 2 Layer Network:
# Validataion accuracy is: 47.3 %
# Epoch [4/20], Step [10/245], Loss: 1.5160
# Epoch [4/20], Step [20/245], Loss: 1.5725
# Epoch [4/20], Step [30/245], Loss: 1.4829
# Epoch [4/20], Step [40/245], Loss: 1.4170
# Epoch [4/20], Step [50/245], Loss: 1.5746
# Epoch [4/20], Step [60/245], Loss: 1.4377
# Epoch [4/20], Step [70/245], Loss: 1.4816
# Epoch [4/20], Step [80/245], Loss: 1.5570
# Epoch [4/20], Step [90/245], Loss: 1.3063
# Epoch [4/20], Step [100/245], Loss: 1.5260
# Epoch [4/20], Step [110/245], Loss: 1.4686
# Epoch [4/20], Step [120/245], Loss: 1.3399
# Epoch [4/20], Step [130/245], Loss: 1.4052
# Epoch [4/20], Step [140/245], Loss: 1.6176
# Epoch [4/20], Step [150/245], Loss: 1.5512
# Epoch [4/20], Step [160/245], Loss: 1.4817
# Epoch [4/20], Step [170/245], Loss: 1.3668
# Epoch [4/20], Step [180/245], Loss: 1.4411
# Epoch [4/20], Step [190/245], Loss: 1.3644
# Epoch [4/20], Step [200/245], Loss: 1.5012
# Epoch [4/20], Step [210/245], Loss: 1.4385
# Epoch [4/20], Step [220/245], Loss: 1.2777
# Epoch [4/20], Step [230/245], Loss: 1.4060
# Epoch [4/20], Step [240/245], Loss: 1.4432
# Train accuracy is: 48.70816326530612 %
# 2 Layer Network:
# Validataion accuracy is: 47.8 %
# Epoch [5/20], Step [10/245], Loss: 1.4822
# Epoch [5/20], Step [20/245], Loss: 1.5126
# Epoch [5/20], Step [30/245], Loss: 1.3880
# Epoch [5/20], Step [40/245], Loss: 1.5994
# Epoch [5/20], Step [50/245], Loss: 1.2547
# Epoch [5/20], Step [60/245], Loss: 1.3153
# Epoch [5/20], Step [70/245], Loss: 1.3335
# Epoch [5/20], Step [80/245], Loss: 1.4763
# Epoch [5/20], Step [90/245], Loss: 1.4360
# Epoch [5/20], Step [100/245], Loss: 1.3399
# Epoch [5/20], Step [110/245], Loss: 1.4522
# Epoch [5/20], Step [120/245], Loss: 1.4951
# Epoch [5/20], Step [130/245], Loss: 1.4698
# Epoch [5/20], Step [140/245], Loss: 1.3269
# Epoch [5/20], Step [150/245], Loss: 1.3387
# Epoch [5/20], Step [160/245], Loss: 1.5141
# Epoch [5/20], Step [170/245], Loss: 1.3605
# Epoch [5/20], Step [180/245], Loss: 1.3735
# Epoch [5/20], Step [190/245], Loss: 1.4009
# Epoch [5/20], Step [200/245], Loss: 1.2112
# Epoch [5/20], Step [210/245], Loss: 1.4513
# Epoch [5/20], Step [220/245], Loss: 1.4543
# Epoch [5/20], Step [230/245], Loss: 1.3842
# Epoch [5/20], Step [240/245], Loss: 1.4042
# Train accuracy is: 50.0265306122449 %
# 2 Layer Network:
# Validataion accuracy is: 48.4 %
# Epoch [6/20], Step [10/245], Loss: 1.4002
# Epoch [6/20], Step [20/245], Loss: 1.3373
# Epoch [6/20], Step [30/245], Loss: 1.4875
# Epoch [6/20], Step [40/245], Loss: 1.4556
# Epoch [6/20], Step [50/245], Loss: 1.3324
# Epoch [6/20], Step [60/245], Loss: 1.3352
# Epoch [6/20], Step [70/245], Loss: 1.4054
# Epoch [6/20], Step [80/245], Loss: 1.3474
# Epoch [6/20], Step [90/245], Loss: 1.4022
# Epoch [6/20], Step [100/245], Loss: 1.4637
# Epoch [6/20], Step [110/245], Loss: 1.4606
# Epoch [6/20], Step [120/245], Loss: 1.2797
# Epoch [6/20], Step [130/245], Loss: 1.4518
# Epoch [6/20], Step [140/245], Loss: 1.3351
# Epoch [6/20], Step [150/245], Loss: 1.3873
# Epoch [6/20], Step [160/245], Loss: 1.3794
# Epoch [6/20], Step [170/245], Loss: 1.5012
# Epoch [6/20], Step [180/245], Loss: 1.3897
# Epoch [6/20], Step [190/245], Loss: 1.5264
# Epoch [6/20], Step [200/245], Loss: 1.3209
# Epoch [6/20], Step [210/245], Loss: 1.4452
# Epoch [6/20], Step [220/245], Loss: 1.4075
# Epoch [6/20], Step [230/245], Loss: 1.5202
# Epoch [6/20], Step [240/245], Loss: 1.3222
# Train accuracy is: 51.20204081632653 %
# 2 Layer Network:
# Validataion accuracy is: 48.5 %
# Epoch [7/20], Step [10/245], Loss: 1.4560
# Epoch [7/20], Step [20/245], Loss: 1.3712
# Epoch [7/20], Step [30/245], Loss: 1.3862
# Epoch [7/20], Step [40/245], Loss: 1.2109
# Epoch [7/20], Step [50/245], Loss: 1.2946
# Epoch [7/20], Step [60/245], Loss: 1.4020
# Epoch [7/20], Step [70/245], Loss: 1.4089
# Epoch [7/20], Step [80/245], Loss: 1.2509
# Epoch [7/20], Step [90/245], Loss: 1.4568
# Epoch [7/20], Step [100/245], Loss: 1.3073
# Epoch [7/20], Step [110/245], Loss: 1.3882
# Epoch [7/20], Step [120/245], Loss: 1.3802
# Epoch [7/20], Step [130/245], Loss: 1.5221
# Epoch [7/20], Step [140/245], Loss: 1.3770
# Epoch [7/20], Step [150/245], Loss: 1.4013
# Epoch [7/20], Step [160/245], Loss: 1.4865
# Epoch [7/20], Step [170/245], Loss: 1.4199
# Epoch [7/20], Step [180/245], Loss: 1.4440
# Epoch [7/20], Step [190/245], Loss: 1.4643
# Epoch [7/20], Step [200/245], Loss: 1.4565
# Epoch [7/20], Step [210/245], Loss: 1.4358
# Epoch [7/20], Step [220/245], Loss: 1.3291
# Epoch [7/20], Step [230/245], Loss: 1.3331
# Epoch [7/20], Step [240/245], Loss: 1.3891
# Train accuracy is: 52.214285714285715 %
# 2 Layer Network:
# Validataion accuracy is: 50.9 %
# Epoch [8/20], Step [10/245], Loss: 1.4153
# Epoch [8/20], Step [20/245], Loss: 1.2793
# Epoch [8/20], Step [30/245], Loss: 1.3205
# Epoch [8/20], Step [40/245], Loss: 1.3817
# Epoch [8/20], Step [50/245], Loss: 1.4035
# Epoch [8/20], Step [60/245], Loss: 1.2689
# Epoch [8/20], Step [70/245], Loss: 1.3384
# Epoch [8/20], Step [80/245], Loss: 1.3794
# Epoch [8/20], Step [90/245], Loss: 1.5449
# Epoch [8/20], Step [100/245], Loss: 1.2476
# Epoch [8/20], Step [110/245], Loss: 1.4057
# Epoch [8/20], Step [120/245], Loss: 1.4865
# Epoch [8/20], Step [130/245], Loss: 1.4153
# Epoch [8/20], Step [140/245], Loss: 1.2563
# Epoch [8/20], Step [150/245], Loss: 1.3250
# Epoch [8/20], Step [160/245], Loss: 1.3650
# Epoch [8/20], Step [170/245], Loss: 1.3835
# Epoch [8/20], Step [180/245], Loss: 1.2752
# Epoch [8/20], Step [190/245], Loss: 1.3574
# Epoch [8/20], Step [200/245], Loss: 1.3512
# Epoch [8/20], Step [210/245], Loss: 1.3658
# Epoch [8/20], Step [220/245], Loss: 1.4238
# Epoch [8/20], Step [230/245], Loss: 1.1902
# Epoch [8/20], Step [240/245], Loss: 1.2969
# Train accuracy is: 52.93877551020408 %
# 2 Layer Network:
# Validataion accuracy is: 47.9 %
# Epoch [9/20], Step [10/245], Loss: 1.3723
# Epoch [9/20], Step [20/245], Loss: 1.3794
# Epoch [9/20], Step [30/245], Loss: 1.3820
# Epoch [9/20], Step [40/245], Loss: 1.1887
# Epoch [9/20], Step [50/245], Loss: 1.4503
# Epoch [9/20], Step [60/245], Loss: 1.2100
# Epoch [9/20], Step [70/245], Loss: 1.3831
# Epoch [9/20], Step [80/245], Loss: 1.2554
# Epoch [9/20], Step [90/245], Loss: 1.1838
# Epoch [9/20], Step [100/245], Loss: 1.3764
# Epoch [9/20], Step [110/245], Loss: 1.3645
# Epoch [9/20], Step [120/245], Loss: 1.2204
# Epoch [9/20], Step [130/245], Loss: 1.4698
# Epoch [9/20], Step [140/245], Loss: 1.3262
# Epoch [9/20], Step [150/245], Loss: 1.4891
# Epoch [9/20], Step [160/245], Loss: 1.3453
# Epoch [9/20], Step [170/245], Loss: 1.2737
# Epoch [9/20], Step [180/245], Loss: 1.2663
# Epoch [9/20], Step [190/245], Loss: 1.3911
# Epoch [9/20], Step [200/245], Loss: 1.2061
# Epoch [9/20], Step [210/245], Loss: 1.3773
# Epoch [9/20], Step [220/245], Loss: 1.2934
# Epoch [9/20], Step [230/245], Loss: 1.3075
# Epoch [9/20], Step [240/245], Loss: 1.2401
# Train accuracy is: 53.608163265306125 %
# 2 Layer Network:
# Validataion accuracy is: 50.5 %
# Epoch [10/20], Step [10/245], Loss: 1.2552
# Epoch [10/20], Step [20/245], Loss: 1.3391
# Epoch [10/20], Step [30/245], Loss: 1.2783
# Epoch [10/20], Step [40/245], Loss: 1.2568
# Epoch [10/20], Step [50/245], Loss: 1.2853
# Epoch [10/20], Step [60/245], Loss: 1.3088
# Epoch [10/20], Step [70/245], Loss: 1.3678
# Epoch [10/20], Step [80/245], Loss: 1.1971
# Epoch [10/20], Step [90/245], Loss: 1.3323
# Epoch [10/20], Step [100/245], Loss: 1.2838
# Epoch [10/20], Step [110/245], Loss: 1.2748
# Epoch [10/20], Step [120/245], Loss: 1.3551
# Epoch [10/20], Step [130/245], Loss: 1.2570
# Epoch [10/20], Step [140/245], Loss: 1.2650
# Epoch [10/20], Step [150/245], Loss: 1.2731
# Epoch [10/20], Step [160/245], Loss: 1.2851
# Epoch [10/20], Step [170/245], Loss: 1.2369
# Epoch [10/20], Step [180/245], Loss: 1.4085
# Epoch [10/20], Step [190/245], Loss: 1.3127
# Epoch [10/20], Step [200/245], Loss: 1.2423
# Epoch [10/20], Step [210/245], Loss: 1.4320
# Epoch [10/20], Step [220/245], Loss: 1.2872
# Epoch [10/20], Step [230/245], Loss: 1.2501
# Epoch [10/20], Step [240/245], Loss: 1.3204
# Train accuracy is: 54.66734693877551 %
# 2 Layer Network:
# Validataion accuracy is: 49.7 %
# Epoch [11/20], Step [10/245], Loss: 1.2856
# Epoch [11/20], Step [20/245], Loss: 1.3094
# Epoch [11/20], Step [30/245], Loss: 1.2697
# Epoch [11/20], Step [40/245], Loss: 1.2763
# Epoch [11/20], Step [50/245], Loss: 1.1975
# Epoch [11/20], Step [60/245], Loss: 1.2916
# Epoch [11/20], Step [70/245], Loss: 1.5477
# Epoch [11/20], Step [80/245], Loss: 1.3097
# Epoch [11/20], Step [90/245], Loss: 1.3370
# Epoch [11/20], Step [100/245], Loss: 1.2688
# Epoch [11/20], Step [110/245], Loss: 1.2313
# Epoch [11/20], Step [120/245], Loss: 1.3532
# Epoch [11/20], Step [130/245], Loss: 1.2777
# Epoch [11/20], Step [140/245], Loss: 1.3067
# Epoch [11/20], Step [150/245], Loss: 1.3139
# Epoch [11/20], Step [160/245], Loss: 1.1957
# Epoch [11/20], Step [170/245], Loss: 1.3642
# Epoch [11/20], Step [180/245], Loss: 1.1692
# Epoch [11/20], Step [190/245], Loss: 1.3903
# Epoch [11/20], Step [200/245], Loss: 1.2960
# Epoch [11/20], Step [210/245], Loss: 1.2912
# Epoch [11/20], Step [220/245], Loss: 1.3295
# Epoch [11/20], Step [230/245], Loss: 1.1983
# Epoch [11/20], Step [240/245], Loss: 1.2230
# Train accuracy is: 54.71632653061224 %
# 2 Layer Network:
# Validataion accuracy is: 51.0 %
# Epoch [12/20], Step [10/245], Loss: 1.3250
# Epoch [12/20], Step [20/245], Loss: 1.3192
# Epoch [12/20], Step [30/245], Loss: 1.2746
# Epoch [12/20], Step [40/245], Loss: 1.2768
# Epoch [12/20], Step [50/245], Loss: 1.3444
# Epoch [12/20], Step [60/245], Loss: 1.2545
# Epoch [12/20], Step [70/245], Loss: 1.2972
# Epoch [12/20], Step [80/245], Loss: 1.1838
# Epoch [12/20], Step [90/245], Loss: 1.1395
# Epoch [12/20], Step [100/245], Loss: 1.2228
# Epoch [12/20], Step [110/245], Loss: 1.2269
# Epoch [12/20], Step [120/245], Loss: 1.2936
# Epoch [12/20], Step [130/245], Loss: 1.1756
# Epoch [12/20], Step [140/245], Loss: 1.2005
# Epoch [12/20], Step [150/245], Loss: 1.3992
# Epoch [12/20], Step [160/245], Loss: 1.3349
# Epoch [12/20], Step [170/245], Loss: 1.2534
# Epoch [12/20], Step [180/245], Loss: 1.4602
# Epoch [12/20], Step [190/245], Loss: 1.4300
# Epoch [12/20], Step [200/245], Loss: 1.3177
# Epoch [12/20], Step [210/245], Loss: 1.2946
# Epoch [12/20], Step [220/245], Loss: 1.3538
# Epoch [12/20], Step [230/245], Loss: 1.3459
# Epoch [12/20], Step [240/245], Loss: 1.2702
# Train accuracy is: 55.26326530612245 %
# 2 Layer Network:
# Validataion accuracy is: 51.4 %
# Epoch [13/20], Step [10/245], Loss: 1.2505
# Epoch [13/20], Step [20/245], Loss: 1.2620
# Epoch [13/20], Step [30/245], Loss: 1.1998
# Epoch [13/20], Step [40/245], Loss: 1.2841
# Epoch [13/20], Step [50/245], Loss: 1.1984
# Epoch [13/20], Step [60/245], Loss: 1.4090
# Epoch [13/20], Step [70/245], Loss: 1.1724
# Epoch [13/20], Step [80/245], Loss: 1.3564
# Epoch [13/20], Step [90/245], Loss: 1.3175
# Epoch [13/20], Step [100/245], Loss: 1.3243
# Epoch [13/20], Step [110/245], Loss: 1.3147
# Epoch [13/20], Step [120/245], Loss: 1.2279
# Epoch [13/20], Step [130/245], Loss: 1.2730
# Epoch [13/20], Step [140/245], Loss: 1.2438
# Epoch [13/20], Step [150/245], Loss: 1.3373
# Epoch [13/20], Step [160/245], Loss: 1.3148
# Epoch [13/20], Step [170/245], Loss: 1.3638
# Epoch [13/20], Step [180/245], Loss: 1.2979
# Epoch [13/20], Step [190/245], Loss: 1.3144
# Epoch [13/20], Step [200/245], Loss: 1.2946
# Epoch [13/20], Step [210/245], Loss: 1.3495
# Epoch [13/20], Step [220/245], Loss: 1.2448
# Epoch [13/20], Step [230/245], Loss: 1.4166
# Epoch [13/20], Step [240/245], Loss: 1.3185
# Train accuracy is: 55.85918367346939 %
# 2 Layer Network:
# Validataion accuracy is: 50.4 %
# Epoch [14/20], Step [10/245], Loss: 1.3024
# Epoch [14/20], Step [20/245], Loss: 1.2437
# Epoch [14/20], Step [30/245], Loss: 1.3167
# Epoch [14/20], Step [40/245], Loss: 1.2734
# Epoch [14/20], Step [50/245], Loss: 1.1807
# Epoch [14/20], Step [60/245], Loss: 1.2727
# Epoch [14/20], Step [70/245], Loss: 1.2539
# Epoch [14/20], Step [80/245], Loss: 1.2894
# Epoch [14/20], Step [90/245], Loss: 1.2609
# Epoch [14/20], Step [100/245], Loss: 1.2437
# Epoch [14/20], Step [110/245], Loss: 1.3568
# Epoch [14/20], Step [120/245], Loss: 1.3770
# Epoch [14/20], Step [130/245], Loss: 1.1678
# Epoch [14/20], Step [140/245], Loss: 1.2682
# Epoch [14/20], Step [150/245], Loss: 1.1609
# Epoch [14/20], Step [160/245], Loss: 1.3461
# Epoch [14/20], Step [170/245], Loss: 1.3422
# Epoch [14/20], Step [180/245], Loss: 1.3054
# Epoch [14/20], Step [190/245], Loss: 1.3743
# Epoch [14/20], Step [200/245], Loss: 1.2724
# Epoch [14/20], Step [210/245], Loss: 1.1040
# Epoch [14/20], Step [220/245], Loss: 1.1376
# Epoch [14/20], Step [230/245], Loss: 1.3442
# Epoch [14/20], Step [240/245], Loss: 1.2562
# Train accuracy is: 56.51632653061225 %
# 2 Layer Network:
# Validataion accuracy is: 51.8 %
# Epoch [15/20], Step [10/245], Loss: 1.1869
# Epoch [15/20], Step [20/245], Loss: 1.3102
# Epoch [15/20], Step [30/245], Loss: 1.2566
# Epoch [15/20], Step [40/245], Loss: 1.2637
# Epoch [15/20], Step [50/245], Loss: 1.1413
# Epoch [15/20], Step [60/245], Loss: 1.2729
# Epoch [15/20], Step [70/245], Loss: 1.2088
# Epoch [15/20], Step [80/245], Loss: 1.2597
# Epoch [15/20], Step [90/245], Loss: 1.3344
# Epoch [15/20], Step [100/245], Loss: 1.3050
# Epoch [15/20], Step [110/245], Loss: 1.3212
# Epoch [15/20], Step [120/245], Loss: 1.3084
# Epoch [15/20], Step [130/245], Loss: 1.1685
# Epoch [15/20], Step [140/245], Loss: 1.3040
# Epoch [15/20], Step [150/245], Loss: 1.1976
# Epoch [15/20], Step [160/245], Loss: 1.2786
# Epoch [15/20], Step [170/245], Loss: 1.2556
# Epoch [15/20], Step [180/245], Loss: 1.1489
# Epoch [15/20], Step [190/245], Loss: 1.4029
# Epoch [15/20], Step [200/245], Loss: 1.2422
# Epoch [15/20], Step [210/245], Loss: 1.1817
# Epoch [15/20], Step [220/245], Loss: 1.2527
# Epoch [15/20], Step [230/245], Loss: 1.2934
# Epoch [15/20], Step [240/245], Loss: 1.2586
# Train accuracy is: 56.65714285714286 %
# 2 Layer Network:
# Validataion accuracy is: 49.9 %
# Epoch [16/20], Step [10/245], Loss: 1.2131
# Epoch [16/20], Step [20/245], Loss: 1.1932
# Epoch [16/20], Step [30/245], Loss: 1.2364
# Epoch [16/20], Step [40/245], Loss: 1.1339
# Epoch [16/20], Step [50/245], Loss: 1.2680
# Epoch [16/20], Step [60/245], Loss: 1.1917
# Epoch [16/20], Step [70/245], Loss: 1.2067
# Epoch [16/20], Step [80/245], Loss: 1.2691
# Epoch [16/20], Step [90/245], Loss: 1.2771
# Epoch [16/20], Step [100/245], Loss: 1.1656
# Epoch [16/20], Step [110/245], Loss: 1.3247
# Epoch [16/20], Step [120/245], Loss: 1.2524
# Epoch [16/20], Step [130/245], Loss: 1.3647
# Epoch [16/20], Step [140/245], Loss: 1.2836
# Epoch [16/20], Step [150/245], Loss: 1.2226
# Epoch [16/20], Step [160/245], Loss: 1.2311
# Epoch [16/20], Step [170/245], Loss: 1.2640
# Epoch [16/20], Step [180/245], Loss: 1.1415
# Epoch [16/20], Step [190/245], Loss: 1.2768
# Epoch [16/20], Step [200/245], Loss: 1.1359
# Epoch [16/20], Step [210/245], Loss: 1.2696
# Epoch [16/20], Step [220/245], Loss: 1.3009
# Epoch [16/20], Step [230/245], Loss: 1.2020
# Epoch [16/20], Step [240/245], Loss: 1.2903
# Train accuracy is: 56.9734693877551 %
# 2 Layer Network:
# Validataion accuracy is: 50.0 %
# Epoch [17/20], Step [10/245], Loss: 1.2245
# Epoch [17/20], Step [20/245], Loss: 1.2344
# Epoch [17/20], Step [30/245], Loss: 1.3062
# Epoch [17/20], Step [40/245], Loss: 1.1805
# Epoch [17/20], Step [50/245], Loss: 1.2126
# Epoch [17/20], Step [60/245], Loss: 1.3155
# Epoch [17/20], Step [70/245], Loss: 1.3714
# Epoch [17/20], Step [80/245], Loss: 1.2317
# Epoch [17/20], Step [90/245], Loss: 1.2300
# Epoch [17/20], Step [100/245], Loss: 1.1978
# Epoch [17/20], Step [110/245], Loss: 1.2453
# Epoch [17/20], Step [120/245], Loss: 1.1948
# Epoch [17/20], Step [130/245], Loss: 1.1444
# Epoch [17/20], Step [140/245], Loss: 1.2665
# Epoch [17/20], Step [150/245], Loss: 1.2565
# Epoch [17/20], Step [160/245], Loss: 1.2641
# Epoch [17/20], Step [170/245], Loss: 1.3317
# Epoch [17/20], Step [180/245], Loss: 1.2125
# Epoch [17/20], Step [190/245], Loss: 1.2190
# Epoch [17/20], Step [200/245], Loss: 1.2035
# Epoch [17/20], Step [210/245], Loss: 1.1438
# Epoch [17/20], Step [220/245], Loss: 1.1907
# Epoch [17/20], Step [230/245], Loss: 1.1589
# Epoch [17/20], Step [240/245], Loss: 1.1804
# Train accuracy is: 57.59591836734694 %
# 2 Layer Network:
# Validataion accuracy is: 51.2 %
# Epoch [18/20], Step [10/245], Loss: 1.0382
# Epoch [18/20], Step [20/245], Loss: 1.2625
# Epoch [18/20], Step [30/245], Loss: 1.1771
# Epoch [18/20], Step [40/245], Loss: 1.3175
# Epoch [18/20], Step [50/245], Loss: 1.2092
# Epoch [18/20], Step [60/245], Loss: 1.2655
# Epoch [18/20], Step [70/245], Loss: 1.2052
# Epoch [18/20], Step [80/245], Loss: 1.2148
# Epoch [18/20], Step [90/245], Loss: 1.4222
# Epoch [18/20], Step [100/245], Loss: 1.1380
# Epoch [18/20], Step [110/245], Loss: 1.1374
# Epoch [18/20], Step [120/245], Loss: 1.2188
# Epoch [18/20], Step [130/245], Loss: 1.2060
# Epoch [18/20], Step [140/245], Loss: 1.2657
# Epoch [18/20], Step [150/245], Loss: 1.3135
# Epoch [18/20], Step [160/245], Loss: 1.2308
# Epoch [18/20], Step [170/245], Loss: 1.1451
# Epoch [18/20], Step [180/245], Loss: 1.1557
# Epoch [18/20], Step [190/245], Loss: 1.1777
# Epoch [18/20], Step [200/245], Loss: 1.2117
# Epoch [18/20], Step [210/245], Loss: 1.0734
# Epoch [18/20], Step [220/245], Loss: 1.1763
# Epoch [18/20], Step [230/245], Loss: 1.2017
# Epoch [18/20], Step [240/245], Loss: 1.3922
# Train accuracy is: 58.012244897959185 %
# 2 Layer Network:
# Validataion accuracy is: 53.4 %
# Epoch [19/20], Step [10/245], Loss: 1.1444
# Epoch [19/20], Step [20/245], Loss: 1.1479
# Epoch [19/20], Step [30/245], Loss: 1.0827
# Epoch [19/20], Step [40/245], Loss: 1.1418
# Epoch [19/20], Step [50/245], Loss: 1.2213
# Epoch [19/20], Step [60/245], Loss: 1.2554
# Epoch [19/20], Step [70/245], Loss: 1.2202
# Epoch [19/20], Step [80/245], Loss: 1.3174
# Epoch [19/20], Step [90/245], Loss: 1.1802
# Epoch [19/20], Step [100/245], Loss: 1.1909
# Epoch [19/20], Step [110/245], Loss: 1.2052
# Epoch [19/20], Step [120/245], Loss: 1.2475
# Epoch [19/20], Step [130/245], Loss: 1.3239
# Epoch [19/20], Step [140/245], Loss: 1.2515
# Epoch [19/20], Step [150/245], Loss: 1.2363
# Epoch [19/20], Step [160/245], Loss: 1.1763
# Epoch [19/20], Step [170/245], Loss: 1.1281
# Epoch [19/20], Step [180/245], Loss: 1.1214
# Epoch [19/20], Step [190/245], Loss: 1.1670
# Epoch [19/20], Step [200/245], Loss: 1.3138
# Epoch [19/20], Step [210/245], Loss: 1.2584
# Epoch [19/20], Step [220/245], Loss: 1.3324
# Epoch [19/20], Step [230/245], Loss: 1.2607
# Epoch [19/20], Step [240/245], Loss: 1.2609
# Train accuracy is: 57.8734693877551 %
# 2 Layer Network:
# Validataion accuracy is: 52.2 %
# Epoch [20/20], Step [10/245], Loss: 1.2798
# Epoch [20/20], Step [20/245], Loss: 1.1005
# Epoch [20/20], Step [30/245], Loss: 1.2888
# Epoch [20/20], Step [40/245], Loss: 1.2152
# Epoch [20/20], Step [50/245], Loss: 1.1614
# Epoch [20/20], Step [60/245], Loss: 1.2604
# Epoch [20/20], Step [70/245], Loss: 1.2423
# Epoch [20/20], Step [80/245], Loss: 1.1609
# Epoch [20/20], Step [90/245], Loss: 1.3087
# Epoch [20/20], Step [100/245], Loss: 1.2678
# Epoch [20/20], Step [110/245], Loss: 1.2523
# Epoch [20/20], Step [120/245], Loss: 1.3050
# Epoch [20/20], Step [130/245], Loss: 1.1918
# Epoch [20/20], Step [140/245], Loss: 1.1230
# Epoch [20/20], Step [150/245], Loss: 1.2087
# Epoch [20/20], Step [160/245], Loss: 1.2789
# Epoch [20/20], Step [170/245], Loss: 1.2194
# Epoch [20/20], Step [180/245], Loss: 1.2710
# Epoch [20/20], Step [190/245], Loss: 1.3461
# Epoch [20/20], Step [200/245], Loss: 1.2572
# Epoch [20/20], Step [210/245], Loss: 1.0907
# Epoch [20/20], Step [220/245], Loss: 1.2107
# Epoch [20/20], Step [230/245], Loss: 1.2516
# Epoch [20/20], Step [240/245], Loss: 1.1542
# Train accuracy is: 58.43061224489796 %
# 2 Layer Network:
# Validataion accuracy is: 52.5 %
# Final validation accuracy for different layers [52.5]
# Epoch [1/20], Step [10/245], Loss: 2.1451
# Epoch [1/20], Step [20/245], Loss: 2.0832
# Epoch [1/20], Step [30/245], Loss: 1.9871
# Epoch [1/20], Step [40/245], Loss: 1.8725
# Epoch [1/20], Step [50/245], Loss: 1.8426
# Epoch [1/20], Step [60/245], Loss: 1.7895
# Epoch [1/20], Step [70/245], Loss: 1.7721
# Epoch [1/20], Step [80/245], Loss: 1.8103
# Epoch [1/20], Step [90/245], Loss: 1.7981
# Epoch [1/20], Step [100/245], Loss: 1.8167
# Epoch [1/20], Step [110/245], Loss: 1.7936
# Epoch [1/20], Step [120/245], Loss: 1.6485
# Epoch [1/20], Step [130/245], Loss: 1.7011
# Epoch [1/20], Step [140/245], Loss: 1.6977
# Epoch [1/20], Step [150/245], Loss: 1.5865
# Epoch [1/20], Step [160/245], Loss: 1.7629
# Epoch [1/20], Step [170/245], Loss: 1.7165
# Epoch [1/20], Step [180/245], Loss: 1.6983
# Epoch [1/20], Step [190/245], Loss: 1.7339
# Epoch [1/20], Step [200/245], Loss: 1.5980
# Epoch [1/20], Step [210/245], Loss: 1.7133
# Epoch [1/20], Step [220/245], Loss: 1.6361
# Epoch [1/20], Step [230/245], Loss: 1.6083
# Epoch [1/20], Step [240/245], Loss: 1.6202
# Train accuracy is: 36.13265306122449 %
# 3 Layer Network:
# Validataion accuracy is: 43.4 %
# Epoch [2/20], Step [10/245], Loss: 1.6298
# Epoch [2/20], Step [20/245], Loss: 1.6107
# Epoch [2/20], Step [30/245], Loss: 1.5157
# Epoch [2/20], Step [40/245], Loss: 1.5572
# Epoch [2/20], Step [50/245], Loss: 1.6596
# Epoch [2/20], Step [60/245], Loss: 1.7196
# Epoch [2/20], Step [70/245], Loss: 1.6059
# Epoch [2/20], Step [80/245], Loss: 1.5823
# Epoch [2/20], Step [90/245], Loss: 1.5797
# Epoch [2/20], Step [100/245], Loss: 1.4994
# Epoch [2/20], Step [110/245], Loss: 1.6404
# Epoch [2/20], Step [120/245], Loss: 1.5753
# Epoch [2/20], Step [130/245], Loss: 1.5147
# Epoch [2/20], Step [140/245], Loss: 1.5134
# Epoch [2/20], Step [150/245], Loss: 1.5732
# Epoch [2/20], Step [160/245], Loss: 1.5969
# Epoch [2/20], Step [170/245], Loss: 1.5863
# Epoch [2/20], Step [180/245], Loss: 1.5500
# Epoch [2/20], Step [190/245], Loss: 1.5415
# Epoch [2/20], Step [200/245], Loss: 1.5106
# Epoch [2/20], Step [210/245], Loss: 1.5432
# Epoch [2/20], Step [220/245], Loss: 1.5178
# Epoch [2/20], Step [230/245], Loss: 1.7052
# Epoch [2/20], Step [240/245], Loss: 1.4907
# Train accuracy is: 44.381632653061224 %
# 3 Layer Network:
# Validataion accuracy is: 46.7 %
# Epoch [3/20], Step [10/245], Loss: 1.5254
# Epoch [3/20], Step [20/245], Loss: 1.5325
# Epoch [3/20], Step [30/245], Loss: 1.4923
# Epoch [3/20], Step [40/245], Loss: 1.5152
# Epoch [3/20], Step [50/245], Loss: 1.5937
# Epoch [3/20], Step [60/245], Loss: 1.4586
# Epoch [3/20], Step [70/245], Loss: 1.5318
# Epoch [3/20], Step [80/245], Loss: 1.4967
# Epoch [3/20], Step [90/245], Loss: 1.5606
# Epoch [3/20], Step [100/245], Loss: 1.5471
# Epoch [3/20], Step [110/245], Loss: 1.5468
# Epoch [3/20], Step [120/245], Loss: 1.4416
# Epoch [3/20], Step [130/245], Loss: 1.4246
# Epoch [3/20], Step [140/245], Loss: 1.5538
# Epoch [3/20], Step [150/245], Loss: 1.4291
# Epoch [3/20], Step [160/245], Loss: 1.5471
# Epoch [3/20], Step [170/245], Loss: 1.5007
# Epoch [3/20], Step [180/245], Loss: 1.5589
# Epoch [3/20], Step [190/245], Loss: 1.5176
# Epoch [3/20], Step [200/245], Loss: 1.3738
# Epoch [3/20], Step [210/245], Loss: 1.6024
# Epoch [3/20], Step [220/245], Loss: 1.5153
# Epoch [3/20], Step [230/245], Loss: 1.5118
# Epoch [3/20], Step [240/245], Loss: 1.5424
# Train accuracy is: 47.159183673469386 %
# 3 Layer Network:
# Validataion accuracy is: 47.3 %
# Epoch [4/20], Step [10/245], Loss: 1.5265
# Epoch [4/20], Step [20/245], Loss: 1.4726
# Epoch [4/20], Step [30/245], Loss: 1.5622
# Epoch [4/20], Step [40/245], Loss: 1.4668
# Epoch [4/20], Step [50/245], Loss: 1.3777
# Epoch [4/20], Step [60/245], Loss: 1.5198
# Epoch [4/20], Step [70/245], Loss: 1.6341
# Epoch [4/20], Step [80/245], Loss: 1.3989
# Epoch [4/20], Step [90/245], Loss: 1.4624
# Epoch [4/20], Step [100/245], Loss: 1.5748
# Epoch [4/20], Step [110/245], Loss: 1.4689
# Epoch [4/20], Step [120/245], Loss: 1.5253
# Epoch [4/20], Step [130/245], Loss: 1.3582
# Epoch [4/20], Step [140/245], Loss: 1.4684
# Epoch [4/20], Step [150/245], Loss: 1.5126
# Epoch [4/20], Step [160/245], Loss: 1.4095
# Epoch [4/20], Step [170/245], Loss: 1.4794
# Epoch [4/20], Step [180/245], Loss: 1.4046
# Epoch [4/20], Step [190/245], Loss: 1.4605
# Epoch [4/20], Step [200/245], Loss: 1.4596
# Epoch [4/20], Step [210/245], Loss: 1.5146
# Epoch [4/20], Step [220/245], Loss: 1.4900
# Epoch [4/20], Step [230/245], Loss: 1.4488
# Epoch [4/20], Step [240/245], Loss: 1.4314
# Train accuracy is: 48.87755102040816 %
# 3 Layer Network:
# Validataion accuracy is: 46.4 %
# Epoch [5/20], Step [10/245], Loss: 1.4703
# Epoch [5/20], Step [20/245], Loss: 1.3912
# Epoch [5/20], Step [30/245], Loss: 1.3961
# Epoch [5/20], Step [40/245], Loss: 1.4286
# Epoch [5/20], Step [50/245], Loss: 1.3373
# Epoch [5/20], Step [60/245], Loss: 1.4035
# Epoch [5/20], Step [70/245], Loss: 1.2964
# Epoch [5/20], Step [80/245], Loss: 1.3994
# Epoch [5/20], Step [90/245], Loss: 1.4542
# Epoch [5/20], Step [100/245], Loss: 1.3053
# Epoch [5/20], Step [110/245], Loss: 1.4067
# Epoch [5/20], Step [120/245], Loss: 1.3605
# Epoch [5/20], Step [130/245], Loss: 1.3482
# Epoch [5/20], Step [140/245], Loss: 1.4217
# Epoch [5/20], Step [150/245], Loss: 1.4500
# Epoch [5/20], Step [160/245], Loss: 1.5172
# Epoch [5/20], Step [170/245], Loss: 1.4410
# Epoch [5/20], Step [180/245], Loss: 1.2251
# Epoch [5/20], Step [190/245], Loss: 1.4972
# Epoch [5/20], Step [200/245], Loss: 1.4108
# Epoch [5/20], Step [210/245], Loss: 1.4566
# Epoch [5/20], Step [220/245], Loss: 1.4046
# Epoch [5/20], Step [230/245], Loss: 1.3628
# Epoch [5/20], Step [240/245], Loss: 1.4931
# Train accuracy is: 50.371428571428574 %
# 3 Layer Network:
# Validataion accuracy is: 49.2 %
# Epoch [6/20], Step [10/245], Loss: 1.3784
# Epoch [6/20], Step [20/245], Loss: 1.3807
# Epoch [6/20], Step [30/245], Loss: 1.3765
# Epoch [6/20], Step [40/245], Loss: 1.3391
# Epoch [6/20], Step [50/245], Loss: 1.3905
# Epoch [6/20], Step [60/245], Loss: 1.4731
# Epoch [6/20], Step [70/245], Loss: 1.3076
# Epoch [6/20], Step [80/245], Loss: 1.3570
# Epoch [6/20], Step [90/245], Loss: 1.3517
# Epoch [6/20], Step [100/245], Loss: 1.3361
# Epoch [6/20], Step [110/245], Loss: 1.4059
# Epoch [6/20], Step [120/245], Loss: 1.3931
# Epoch [6/20], Step [130/245], Loss: 1.4492
# Epoch [6/20], Step [140/245], Loss: 1.3262
# Epoch [6/20], Step [150/245], Loss: 1.4606
# Epoch [6/20], Step [160/245], Loss: 1.3731
# Epoch [6/20], Step [170/245], Loss: 1.4207
# Epoch [6/20], Step [180/245], Loss: 1.3121
# Epoch [6/20], Step [190/245], Loss: 1.2536
# Epoch [6/20], Step [200/245], Loss: 1.6096
# Epoch [6/20], Step [210/245], Loss: 1.3515
# Epoch [6/20], Step [220/245], Loss: 1.4016
# Epoch [6/20], Step [230/245], Loss: 1.4513
# Epoch [6/20], Step [240/245], Loss: 1.2800
# Train accuracy is: 51.375510204081635 %
# 3 Layer Network:
# Validataion accuracy is: 49.4 %
# Epoch [7/20], Step [10/245], Loss: 1.2859
# Epoch [7/20], Step [20/245], Loss: 1.2946
# Epoch [7/20], Step [30/245], Loss: 1.3955
# Epoch [7/20], Step [40/245], Loss: 1.4129
# Epoch [7/20], Step [50/245], Loss: 1.2501
# Epoch [7/20], Step [60/245], Loss: 1.4340
# Epoch [7/20], Step [70/245], Loss: 1.3852
# Epoch [7/20], Step [80/245], Loss: 1.4524
# Epoch [7/20], Step [90/245], Loss: 1.4798
# Epoch [7/20], Step [100/245], Loss: 1.2521
# Epoch [7/20], Step [110/245], Loss: 1.2817
# Epoch [7/20], Step [120/245], Loss: 1.3616
# Epoch [7/20], Step [130/245], Loss: 1.3060
# Epoch [7/20], Step [140/245], Loss: 1.2682
# Epoch [7/20], Step [150/245], Loss: 1.4649
# Epoch [7/20], Step [160/245], Loss: 1.4306
# Epoch [7/20], Step [170/245], Loss: 1.2854
# Epoch [7/20], Step [180/245], Loss: 1.3717
# Epoch [7/20], Step [190/245], Loss: 1.2344
# Epoch [7/20], Step [200/245], Loss: 1.2018
# Epoch [7/20], Step [210/245], Loss: 1.3882
# Epoch [7/20], Step [220/245], Loss: 1.3711
# Epoch [7/20], Step [230/245], Loss: 1.2848
# Epoch [7/20], Step [240/245], Loss: 1.3580
# Train accuracy is: 51.9734693877551 %
# 3 Layer Network:
# Validataion accuracy is: 49.8 %
# Epoch [8/20], Step [10/245], Loss: 1.2506
# Epoch [8/20], Step [20/245], Loss: 1.4138
# Epoch [8/20], Step [30/245], Loss: 1.3168
# Epoch [8/20], Step [40/245], Loss: 1.3717
# Epoch [8/20], Step [50/245], Loss: 1.3272
# Epoch [8/20], Step [60/245], Loss: 1.3706
# Epoch [8/20], Step [70/245], Loss: 1.4101
# Epoch [8/20], Step [80/245], Loss: 1.2019
# Epoch [8/20], Step [90/245], Loss: 1.3315
# Epoch [8/20], Step [100/245], Loss: 1.3202
# Epoch [8/20], Step [110/245], Loss: 1.3650
# Epoch [8/20], Step [120/245], Loss: 1.2416
# Epoch [8/20], Step [130/245], Loss: 1.4224
# Epoch [8/20], Step [140/245], Loss: 1.3248
# Epoch [8/20], Step [150/245], Loss: 1.3369
# Epoch [8/20], Step [160/245], Loss: 1.3289
# Epoch [8/20], Step [170/245], Loss: 1.3376
# Epoch [8/20], Step [180/245], Loss: 1.3895
# Epoch [8/20], Step [190/245], Loss: 1.4055
# Epoch [8/20], Step [200/245], Loss: 1.3847
# Epoch [8/20], Step [210/245], Loss: 1.3568
# Epoch [8/20], Step [220/245], Loss: 1.2405
# Epoch [8/20], Step [230/245], Loss: 1.4885
# Epoch [8/20], Step [240/245], Loss: 1.4903
# Train accuracy is: 52.987755102040815 %
# 3 Layer Network:
# Validataion accuracy is: 49.8 %
# Epoch [9/20], Step [10/245], Loss: 1.2584
# Epoch [9/20], Step [20/245], Loss: 1.3628
# Epoch [9/20], Step [30/245], Loss: 1.4150
# Epoch [9/20], Step [40/245], Loss: 1.3349
# Epoch [9/20], Step [50/245], Loss: 1.3025
# Epoch [9/20], Step [60/245], Loss: 1.2122
# Epoch [9/20], Step [70/245], Loss: 1.3455
# Epoch [9/20], Step [80/245], Loss: 1.3149
# Epoch [9/20], Step [90/245], Loss: 1.4196
# Epoch [9/20], Step [100/245], Loss: 1.4100
# Epoch [9/20], Step [110/245], Loss: 1.2377
# Epoch [9/20], Step [120/245], Loss: 1.2186
# Epoch [9/20], Step [130/245], Loss: 1.2112
# Epoch [9/20], Step [140/245], Loss: 1.3882
# Epoch [9/20], Step [150/245], Loss: 1.3305
# Epoch [9/20], Step [160/245], Loss: 1.2269
# Epoch [9/20], Step [170/245], Loss: 1.2842
# Epoch [9/20], Step [180/245], Loss: 1.3770
# Epoch [9/20], Step [190/245], Loss: 1.3511
# Epoch [9/20], Step [200/245], Loss: 1.3733
# Epoch [9/20], Step [210/245], Loss: 1.1726
# Epoch [9/20], Step [220/245], Loss: 1.3885
# Epoch [9/20], Step [230/245], Loss: 1.2621
# Epoch [9/20], Step [240/245], Loss: 1.2837
# Train accuracy is: 53.64081632653061 %
# 3 Layer Network:
# Validataion accuracy is: 50.1 %
# Epoch [10/20], Step [10/245], Loss: 1.2567
# Epoch [10/20], Step [20/245], Loss: 1.2670
# Epoch [10/20], Step [30/245], Loss: 1.3600
# Epoch [10/20], Step [40/245], Loss: 1.2190
# Epoch [10/20], Step [50/245], Loss: 1.3562
# Epoch [10/20], Step [60/245], Loss: 1.3552
# Epoch [10/20], Step [70/245], Loss: 1.2616
# Epoch [10/20], Step [80/245], Loss: 1.2059
# Epoch [10/20], Step [90/245], Loss: 1.5132
# Epoch [10/20], Step [100/245], Loss: 1.3431
# Epoch [10/20], Step [110/245], Loss: 1.3967
# Epoch [10/20], Step [120/245], Loss: 1.3397
# Epoch [10/20], Step [130/245], Loss: 1.3350
# Epoch [10/20], Step [140/245], Loss: 1.3787
# Epoch [10/20], Step [150/245], Loss: 1.3890
# Epoch [10/20], Step [160/245], Loss: 1.2056
# Epoch [10/20], Step [170/245], Loss: 1.5234
# Epoch [10/20], Step [180/245], Loss: 1.3569
# Epoch [10/20], Step [190/245], Loss: 1.3270
# Epoch [10/20], Step [200/245], Loss: 1.3628
# Epoch [10/20], Step [210/245], Loss: 1.2597
# Epoch [10/20], Step [220/245], Loss: 1.2750
# Epoch [10/20], Step [230/245], Loss: 1.1462
# Epoch [10/20], Step [240/245], Loss: 1.2940
# Train accuracy is: 54.16734693877551 %
# 3 Layer Network:
# Validataion accuracy is: 51.9 %
# Epoch [11/20], Step [10/245], Loss: 1.2874
# Epoch [11/20], Step [20/245], Loss: 1.3864
# Epoch [11/20], Step [30/245], Loss: 1.3661
# Epoch [11/20], Step [40/245], Loss: 1.3004
# Epoch [11/20], Step [50/245], Loss: 1.1959
# Epoch [11/20], Step [60/245], Loss: 1.2949
# Epoch [11/20], Step [70/245], Loss: 1.2968
# Epoch [11/20], Step [80/245], Loss: 1.3767
# Epoch [11/20], Step [90/245], Loss: 1.2953
# Epoch [11/20], Step [100/245], Loss: 1.3021
# Epoch [11/20], Step [110/245], Loss: 1.2704
# Epoch [11/20], Step [120/245], Loss: 1.2257
# Epoch [11/20], Step [130/245], Loss: 1.2047
# Epoch [11/20], Step [140/245], Loss: 1.3954
# Epoch [11/20], Step [150/245], Loss: 1.1261
# Epoch [11/20], Step [160/245], Loss: 1.4046
# Epoch [11/20], Step [170/245], Loss: 1.3680
# Epoch [11/20], Step [180/245], Loss: 1.2883
# Epoch [11/20], Step [190/245], Loss: 1.1696
# Epoch [11/20], Step [200/245], Loss: 1.3474
# Epoch [11/20], Step [210/245], Loss: 1.3492
# Epoch [11/20], Step [220/245], Loss: 1.3693
# Epoch [11/20], Step [230/245], Loss: 1.3559
# Epoch [11/20], Step [240/245], Loss: 1.2547
# Train accuracy is: 54.93877551020408 %
# 3 Layer Network:
# Validataion accuracy is: 50.6 %
# Epoch [12/20], Step [10/245], Loss: 1.2183
# Epoch [12/20], Step [20/245], Loss: 1.2060
# Epoch [12/20], Step [30/245], Loss: 1.1876
# Epoch [12/20], Step [40/245], Loss: 1.3828
# Epoch [12/20], Step [50/245], Loss: 1.1830
# Epoch [12/20], Step [60/245], Loss: 1.3043
# Epoch [12/20], Step [70/245], Loss: 1.2612
# Epoch [12/20], Step [80/245], Loss: 1.3094
# Epoch [12/20], Step [90/245], Loss: 1.2257
# Epoch [12/20], Step [100/245], Loss: 1.3340
# Epoch [12/20], Step [110/245], Loss: 1.2592
# Epoch [12/20], Step [120/245], Loss: 1.2022
# Epoch [12/20], Step [130/245], Loss: 1.3102
# Epoch [12/20], Step [140/245], Loss: 1.3243
# Epoch [12/20], Step [150/245], Loss: 1.3741
# Epoch [12/20], Step [160/245], Loss: 1.2015
# Epoch [12/20], Step [170/245], Loss: 1.3934
# Epoch [12/20], Step [180/245], Loss: 1.3828
# Epoch [12/20], Step [190/245], Loss: 1.3172
# Epoch [12/20], Step [200/245], Loss: 1.2571
# Epoch [12/20], Step [210/245], Loss: 1.1782
# Epoch [12/20], Step [220/245], Loss: 1.3265
# Epoch [12/20], Step [230/245], Loss: 1.1888
# Epoch [12/20], Step [240/245], Loss: 1.2714
# Train accuracy is: 55.36734693877551 %
# 3 Layer Network:
# Validataion accuracy is: 51.5 %
# Epoch [13/20], Step [10/245], Loss: 1.2622
# Epoch [13/20], Step [20/245], Loss: 1.2541
# Epoch [13/20], Step [30/245], Loss: 1.1750
# Epoch [13/20], Step [40/245], Loss: 1.3004
# Epoch [13/20], Step [50/245], Loss: 1.2417
# Epoch [13/20], Step [60/245], Loss: 1.2741
# Epoch [13/20], Step [70/245], Loss: 1.2326
# Epoch [13/20], Step [80/245], Loss: 1.1637
# Epoch [13/20], Step [90/245], Loss: 1.3692
# Epoch [13/20], Step [100/245], Loss: 1.2344
# Epoch [13/20], Step [110/245], Loss: 1.3201
# Epoch [13/20], Step [120/245], Loss: 1.3117
# Epoch [13/20], Step [130/245], Loss: 1.1986
# Epoch [13/20], Step [140/245], Loss: 1.3405
# Epoch [13/20], Step [150/245], Loss: 1.3187
# Epoch [13/20], Step [160/245], Loss: 1.3042
# Epoch [13/20], Step [170/245], Loss: 1.2350
# Epoch [13/20], Step [180/245], Loss: 1.2245
# Epoch [13/20], Step [190/245], Loss: 1.1992
# Epoch [13/20], Step [200/245], Loss: 1.2445
# Epoch [13/20], Step [210/245], Loss: 1.2748
# Epoch [13/20], Step [220/245], Loss: 1.1658
# Epoch [13/20], Step [230/245], Loss: 1.1405
# Epoch [13/20], Step [240/245], Loss: 1.3625
# Train accuracy is: 55.85306122448979 %
# 3 Layer Network:
# Validataion accuracy is: 50.8 %
# Epoch [14/20], Step [10/245], Loss: 1.0681
# Epoch [14/20], Step [20/245], Loss: 1.4189
# Epoch [14/20], Step [30/245], Loss: 1.3870
# Epoch [14/20], Step [40/245], Loss: 1.3411
# Epoch [14/20], Step [50/245], Loss: 1.3069
# Epoch [14/20], Step [60/245], Loss: 1.2557
# Epoch [14/20], Step [70/245], Loss: 1.3270
# Epoch [14/20], Step [80/245], Loss: 1.2616
# Epoch [14/20], Step [90/245], Loss: 1.1926
# Epoch [14/20], Step [100/245], Loss: 1.1912
# Epoch [14/20], Step [110/245], Loss: 1.2317
# Epoch [14/20], Step [120/245], Loss: 1.1950
# Epoch [14/20], Step [130/245], Loss: 1.2074
# Epoch [14/20], Step [140/245], Loss: 1.2731
# Epoch [14/20], Step [150/245], Loss: 1.1774
# Epoch [14/20], Step [160/245], Loss: 1.2902
# Epoch [14/20], Step [170/245], Loss: 1.1172
# Epoch [14/20], Step [180/245], Loss: 1.2759
# Epoch [14/20], Step [190/245], Loss: 1.3155
# Epoch [14/20], Step [200/245], Loss: 1.2439
# Epoch [14/20], Step [210/245], Loss: 1.1041
# Epoch [14/20], Step [220/245], Loss: 1.2667
# Epoch [14/20], Step [230/245], Loss: 1.2043
# Epoch [14/20], Step [240/245], Loss: 1.2520
# Train accuracy is: 56.4 %
# 3 Layer Network:
# Validataion accuracy is: 50.8 %
# Epoch [15/20], Step [10/245], Loss: 1.3129
# Epoch [15/20], Step [20/245], Loss: 1.1084
# Epoch [15/20], Step [30/245], Loss: 1.1686
# Epoch [15/20], Step [40/245], Loss: 1.2751
# Epoch [15/20], Step [50/245], Loss: 1.2051
# Epoch [15/20], Step [60/245], Loss: 1.2559
# Epoch [15/20], Step [70/245], Loss: 1.2886
# Epoch [15/20], Step [80/245], Loss: 1.2028
# Epoch [15/20], Step [90/245], Loss: 1.2623
# Epoch [15/20], Step [100/245], Loss: 1.1544
# Epoch [15/20], Step [110/245], Loss: 1.2414
# Epoch [15/20], Step [120/245], Loss: 1.2373
# Epoch [15/20], Step [130/245], Loss: 1.1403
# Epoch [15/20], Step [140/245], Loss: 1.4114
# Epoch [15/20], Step [150/245], Loss: 1.3354
# Epoch [15/20], Step [160/245], Loss: 1.2386
# Epoch [15/20], Step [170/245], Loss: 1.2205
# Epoch [15/20], Step [180/245], Loss: 1.2527
# Epoch [15/20], Step [190/245], Loss: 1.1658
# Epoch [15/20], Step [200/245], Loss: 1.2140
# Epoch [15/20], Step [210/245], Loss: 1.2328
# Epoch [15/20], Step [220/245], Loss: 1.2696
# Epoch [15/20], Step [230/245], Loss: 1.1564
# Epoch [15/20], Step [240/245], Loss: 1.2488
# Train accuracy is: 56.9734693877551 %
# 3 Layer Network:
# Validataion accuracy is: 50.8 %
# Epoch [16/20], Step [10/245], Loss: 1.2714
# Epoch [16/20], Step [20/245], Loss: 1.3446
# Epoch [16/20], Step [30/245], Loss: 1.3178
# Epoch [16/20], Step [40/245], Loss: 1.1361
# Epoch [16/20], Step [50/245], Loss: 1.2844
# Epoch [16/20], Step [60/245], Loss: 1.1492
# Epoch [16/20], Step [70/245], Loss: 1.2451
# Epoch [16/20], Step [80/245], Loss: 1.4234
# Epoch [16/20], Step [90/245], Loss: 1.2526
# Epoch [16/20], Step [100/245], Loss: 1.3107
# Epoch [16/20], Step [110/245], Loss: 1.2419
# Epoch [16/20], Step [120/245], Loss: 1.3218
# Epoch [16/20], Step [130/245], Loss: 1.1419
# Epoch [16/20], Step [140/245], Loss: 1.1796
# Epoch [16/20], Step [150/245], Loss: 1.2588
# Epoch [16/20], Step [160/245], Loss: 1.2503
# Epoch [16/20], Step [170/245], Loss: 1.3024
# Epoch [16/20], Step [180/245], Loss: 1.2342
# Epoch [16/20], Step [190/245], Loss: 1.3400
# Epoch [16/20], Step [200/245], Loss: 1.2176
# Epoch [16/20], Step [210/245], Loss: 1.2169
# Epoch [16/20], Step [220/245], Loss: 1.1634
# Epoch [16/20], Step [230/245], Loss: 1.2669
# Epoch [16/20], Step [240/245], Loss: 1.1741
# Train accuracy is: 57.09795918367347 %
# 3 Layer Network:
# Validataion accuracy is: 50.3 %
# Epoch [17/20], Step [10/245], Loss: 1.1685
# Epoch [17/20], Step [20/245], Loss: 1.3203
# Epoch [17/20], Step [30/245], Loss: 1.2540
# Epoch [17/20], Step [40/245], Loss: 1.1335
# Epoch [17/20], Step [50/245], Loss: 1.2521
# Epoch [17/20], Step [60/245], Loss: 1.1859
# Epoch [17/20], Step [70/245], Loss: 1.2089
# Epoch [17/20], Step [80/245], Loss: 1.3985
# Epoch [17/20], Step [90/245], Loss: 1.1186
# Epoch [17/20], Step [100/245], Loss: 1.3289
# Epoch [17/20], Step [110/245], Loss: 1.1619
# Epoch [17/20], Step [120/245], Loss: 1.2013
# Epoch [17/20], Step [130/245], Loss: 1.4239
# Epoch [17/20], Step [140/245], Loss: 1.3111
# Epoch [17/20], Step [150/245], Loss: 1.2629
# Epoch [17/20], Step [160/245], Loss: 1.2371
# Epoch [17/20], Step [170/245], Loss: 1.0839
# Epoch [17/20], Step [180/245], Loss: 1.2248
# Epoch [17/20], Step [190/245], Loss: 1.3205
# Epoch [17/20], Step [200/245], Loss: 1.2926
# Epoch [17/20], Step [210/245], Loss: 1.2504
# Epoch [17/20], Step [220/245], Loss: 1.2326
# Epoch [17/20], Step [230/245], Loss: 1.3246
# Epoch [17/20], Step [240/245], Loss: 1.2493
# Train accuracy is: 57.542857142857144 %
# 3 Layer Network:
# Validataion accuracy is: 50.5 %
# Epoch [18/20], Step [10/245], Loss: 1.1817
# Epoch [18/20], Step [20/245], Loss: 1.3418
# Epoch [18/20], Step [30/245], Loss: 1.2092
# Epoch [18/20], Step [40/245], Loss: 1.2198
# Epoch [18/20], Step [50/245], Loss: 1.1627
# Epoch [18/20], Step [60/245], Loss: 1.0966
# Epoch [18/20], Step [70/245], Loss: 1.3126
# Epoch [18/20], Step [80/245], Loss: 1.2130
# Epoch [18/20], Step [90/245], Loss: 1.2231
# Epoch [18/20], Step [100/245], Loss: 1.1733
# Epoch [18/20], Step [110/245], Loss: 1.2140
# Epoch [18/20], Step [120/245], Loss: 1.1695
# Epoch [18/20], Step [130/245], Loss: 1.2068
# Epoch [18/20], Step [140/245], Loss: 1.1968
# Epoch [18/20], Step [150/245], Loss: 1.2336
# Epoch [18/20], Step [160/245], Loss: 1.3228
# Epoch [18/20], Step [170/245], Loss: 1.2930
# Epoch [18/20], Step [180/245], Loss: 1.1787
# Epoch [18/20], Step [190/245], Loss: 1.1108
# Epoch [18/20], Step [200/245], Loss: 1.2285
# Epoch [18/20], Step [210/245], Loss: 1.2220
# Epoch [18/20], Step [220/245], Loss: 1.1528
# Epoch [18/20], Step [230/245], Loss: 1.2674
# Epoch [18/20], Step [240/245], Loss: 1.1171
# Train accuracy is: 57.953061224489794 %
# 3 Layer Network:
# Validataion accuracy is: 52.2 %
# Epoch [19/20], Step [10/245], Loss: 1.2107
# Epoch [19/20], Step [20/245], Loss: 1.1980
# Epoch [19/20], Step [30/245], Loss: 1.2847
# Epoch [19/20], Step [40/245], Loss: 1.1704
# Epoch [19/20], Step [50/245], Loss: 1.2864
# Epoch [19/20], Step [60/245], Loss: 1.1362
# Epoch [19/20], Step [70/245], Loss: 1.3260
# Epoch [19/20], Step [80/245], Loss: 1.1940
# Epoch [19/20], Step [90/245], Loss: 1.3730
# Epoch [19/20], Step [100/245], Loss: 1.1772
# Epoch [19/20], Step [110/245], Loss: 1.2166
# Epoch [19/20], Step [120/245], Loss: 1.2549
# Epoch [19/20], Step [130/245], Loss: 1.1544
# Epoch [19/20], Step [140/245], Loss: 1.2214
# Epoch [19/20], Step [150/245], Loss: 1.3281
# Epoch [19/20], Step [160/245], Loss: 1.1552
# Epoch [19/20], Step [170/245], Loss: 1.2067
# Epoch [19/20], Step [180/245], Loss: 1.2509
# Epoch [19/20], Step [190/245], Loss: 1.2573
# Epoch [19/20], Step [200/245], Loss: 1.1708
# Epoch [19/20], Step [210/245], Loss: 1.1531
# Epoch [19/20], Step [220/245], Loss: 1.1337
# Epoch [19/20], Step [230/245], Loss: 1.3747
# Epoch [19/20], Step [240/245], Loss: 1.2450
# Train accuracy is: 58.03469387755102 %
# 3 Layer Network:
# Validataion accuracy is: 51.1 %
# Epoch [20/20], Step [10/245], Loss: 1.2138
# Epoch [20/20], Step [20/245], Loss: 1.2046
# Epoch [20/20], Step [30/245], Loss: 1.2167
# Epoch [20/20], Step [40/245], Loss: 1.2050
# Epoch [20/20], Step [50/245], Loss: 1.2238
# Epoch [20/20], Step [60/245], Loss: 1.2155
# Epoch [20/20], Step [70/245], Loss: 1.1679
# Epoch [20/20], Step [80/245], Loss: 1.1446
# Epoch [20/20], Step [90/245], Loss: 1.0987
# Epoch [20/20], Step [100/245], Loss: 1.2347
# Epoch [20/20], Step [110/245], Loss: 1.1957
# Epoch [20/20], Step [120/245], Loss: 1.2788
# Epoch [20/20], Step [130/245], Loss: 1.2708
# Epoch [20/20], Step [140/245], Loss: 1.2778
# Epoch [20/20], Step [150/245], Loss: 1.2112
# Epoch [20/20], Step [160/245], Loss: 1.2330
# Epoch [20/20], Step [170/245], Loss: 1.2276
# Epoch [20/20], Step [180/245], Loss: 1.1359
# Epoch [20/20], Step [190/245], Loss: 1.1450
# Epoch [20/20], Step [200/245], Loss: 1.2122
# Epoch [20/20], Step [210/245], Loss: 1.2060
# Epoch [20/20], Step [220/245], Loss: 1.2009
# Epoch [20/20], Step [230/245], Loss: 1.3075
# Epoch [20/20], Step [240/245], Loss: 1.0854
# Train accuracy is: 58.43265306122449 %
# 3 Layer Network:
# Validataion accuracy is: 50.5 %
# Final validation accuracy for different layers [52.5, 50.5]
# Epoch [1/20], Step [10/245], Loss: 2.1784
# Epoch [1/20], Step [20/245], Loss: 2.0175
# Epoch [1/20], Step [30/245], Loss: 1.9580
# Epoch [1/20], Step [40/245], Loss: 1.8211
# Epoch [1/20], Step [50/245], Loss: 1.7501
# Epoch [1/20], Step [60/245], Loss: 1.8233
# Epoch [1/20], Step [70/245], Loss: 1.7393
# Epoch [1/20], Step [80/245], Loss: 1.9522
# Epoch [1/20], Step [90/245], Loss: 1.7528
# Epoch [1/20], Step [100/245], Loss: 1.8139
# Epoch [1/20], Step [110/245], Loss: 1.7879
# Epoch [1/20], Step [120/245], Loss: 1.7606
# Epoch [1/20], Step [130/245], Loss: 1.6359
# Epoch [1/20], Step [140/245], Loss: 1.7025
# Epoch [1/20], Step [150/245], Loss: 1.7723
# Epoch [1/20], Step [160/245], Loss: 1.6173
# Epoch [1/20], Step [170/245], Loss: 1.6545
# Epoch [1/20], Step [180/245], Loss: 1.6829
# Epoch [1/20], Step [190/245], Loss: 1.5506
# Epoch [1/20], Step [200/245], Loss: 1.6002
# Epoch [1/20], Step [210/245], Loss: 1.7173
# Epoch [1/20], Step [220/245], Loss: 1.6608
# Epoch [1/20], Step [230/245], Loss: 1.6993
# Epoch [1/20], Step [240/245], Loss: 1.6574
# Train accuracy is: 36.7530612244898 %
# 4 Layer Network:
# Validataion accuracy is: 42.7 %
# Epoch [2/20], Step [10/245], Loss: 1.5176
# Epoch [2/20], Step [20/245], Loss: 1.5331
# Epoch [2/20], Step [30/245], Loss: 1.5580
# Epoch [2/20], Step [40/245], Loss: 1.6334
# Epoch [2/20], Step [50/245], Loss: 1.6048
# Epoch [2/20], Step [60/245], Loss: 1.5616
# Epoch [2/20], Step [70/245], Loss: 1.7293
# Epoch [2/20], Step [80/245], Loss: 1.6000
# Epoch [2/20], Step [90/245], Loss: 1.5450
# Epoch [2/20], Step [100/245], Loss: 1.5574
# Epoch [2/20], Step [110/245], Loss: 1.5895
# Epoch [2/20], Step [120/245], Loss: 1.4995
# Epoch [2/20], Step [130/245], Loss: 1.4956
# Epoch [2/20], Step [140/245], Loss: 1.5870
# Epoch [2/20], Step [150/245], Loss: 1.5055
# Epoch [2/20], Step [160/245], Loss: 1.5517
# Epoch [2/20], Step [170/245], Loss: 1.6124
# Epoch [2/20], Step [180/245], Loss: 1.6478
# Epoch [2/20], Step [190/245], Loss: 1.5293
# Epoch [2/20], Step [200/245], Loss: 1.5936
# Epoch [2/20], Step [210/245], Loss: 1.4861
# Epoch [2/20], Step [220/245], Loss: 1.4869
# Epoch [2/20], Step [230/245], Loss: 1.4793
# Epoch [2/20], Step [240/245], Loss: 1.4622
# Train accuracy is: 44.41836734693877 %
# 4 Layer Network:
# Validataion accuracy is: 46.6 %
# Epoch [3/20], Step [10/245], Loss: 1.4873
# Epoch [3/20], Step [20/245], Loss: 1.5811
# Epoch [3/20], Step [30/245], Loss: 1.6122
# Epoch [3/20], Step [40/245], Loss: 1.5123
# Epoch [3/20], Step [50/245], Loss: 1.4321
# Epoch [3/20], Step [60/245], Loss: 1.4854
# Epoch [3/20], Step [70/245], Loss: 1.5306
# Epoch [3/20], Step [80/245], Loss: 1.4779
# Epoch [3/20], Step [90/245], Loss: 1.4905
# Epoch [3/20], Step [100/245], Loss: 1.4856
# Epoch [3/20], Step [110/245], Loss: 1.4371
# Epoch [3/20], Step [120/245], Loss: 1.5688
# Epoch [3/20], Step [130/245], Loss: 1.3612
# Epoch [3/20], Step [140/245], Loss: 1.5263
# Epoch [3/20], Step [150/245], Loss: 1.5242
# Epoch [3/20], Step [160/245], Loss: 1.4256
# ...
# Epoch [7/20], Step [80/245], Loss: 1.3205
# Epoch [7/20], Step [90/245], Loss: 1.4388
# Epoch [7/20], Step [100/245], Loss: 1.3195
# Epoch [7/20], Step [110/245], Loss: 1.3140
# Epoch [7/20], Step [120/245], Loss: 1.2310
# Epoch [7/20], Step [130/245], Loss: 1.3895
# Epoch [7/20], Step [140/245], Loss: 1.4638
# Epoch [7/20], Step [150/245], Loss: 1.2927
# Epoch [7/20], Step [160/245], Loss: 1.4659
# Epoch [7/20], Step [170/245], Loss: 1.4074
# Epoch [7/20], Step [180/245], Loss: 1.3639
# Epoch [7/20], Step [190/245], Loss: 1.4961
# Epoch [7/20], Step [200/245], Loss: 1.3155
# Epoch [7/20], Step [210/245], Loss: 1.3399
# Epoch [7/20], Step [220/245], Loss: 1.3043
# Epoch [7/20], Step [230/245], Loss: 1.3195
# Epoch [7/20], Step [240/245], Loss: 1.2982
# Train accuracy is: 51.885714285714286 %
# 6 Layer Network:
# Validataion accuracy is: 47.6 %
# Epoch [8/20], Step [10/245], Loss: 1.3383
# Epoch [8/20], Step [20/245], Loss: 1.2891
# Epoch [8/20], Step [30/245], Loss: 1.3172
# Epoch [8/20], Step [40/245], Loss: 1.2663
# Epoch [8/20], Step [50/245], Loss: 1.2955
# Epoch [8/20], Step [60/245], Loss: 1.3286
# Epoch [8/20], Step [70/245], Loss: 1.3204
# Epoch [8/20], Step [80/245], Loss: 1.4287
# Epoch [8/20], Step [90/245], Loss: 1.2782
# Epoch [8/20], Step [100/245], Loss: 1.3415
# Epoch [8/20], Step [110/245], Loss: 1.4057
# Epoch [8/20], Step [120/245], Loss: 1.2903
# Epoch [8/20], Step [130/245], Loss: 1.2133
# Epoch [8/20], Step [140/245], Loss: 1.3194
# Epoch [8/20], Step [150/245], Loss: 1.3254
# Epoch [8/20], Step [160/245], Loss: 1.2936
# Epoch [8/20], Step [170/245], Loss: 1.3007
# Epoch [8/20], Step [180/245], Loss: 1.3552
# Epoch [8/20], Step [190/245], Loss: 1.3878
# Epoch [8/20], Step [200/245], Loss: 1.4139
# Epoch [8/20], Step [210/245], Loss: 1.4770
# Epoch [8/20], Step [220/245], Loss: 1.2938
# Epoch [8/20], Step [230/245], Loss: 1.2333
# Epoch [8/20], Step [240/245], Loss: 1.4105
# Train accuracy is: 52.70204081632653 %
# 6 Layer Network:
# Validataion accuracy is: 49.8 %
# Epoch [9/20], Step [10/245], Loss: 1.4315
# Epoch [9/20], Step [20/245], Loss: 1.3926
# Epoch [9/20], Step [30/245], Loss: 1.3652
# Epoch [9/20], Step [40/245], Loss: 1.4174
# Epoch [9/20], Step [50/245], Loss: 1.2440
# Epoch [9/20], Step [60/245], Loss: 1.3602
# Epoch [9/20], Step [70/245], Loss: 1.2940
# Epoch [9/20], Step [80/245], Loss: 1.2904
# Epoch [9/20], Step [90/245], Loss: 1.3697
# Epoch [9/20], Step [100/245], Loss: 1.2730
# Epoch [9/20], Step [110/245], Loss: 1.3393
# Epoch [9/20], Step [120/245], Loss: 1.2324
# Epoch [9/20], Step [130/245], Loss: 1.3015
# Epoch [9/20], Step [140/245], Loss: 1.3937
# Epoch [9/20], Step [150/245], Loss: 1.3038
# Epoch [9/20], Step [160/245], Loss: 1.4641
# Epoch [9/20], Step [170/245], Loss: 1.3467
# Epoch [9/20], Step [180/245], Loss: 1.3027
# Epoch [9/20], Step [190/245], Loss: 1.2970
# Epoch [9/20], Step [200/245], Loss: 1.1756
# Epoch [9/20], Step [210/245], Loss: 1.2677
# Epoch [9/20], Step [220/245], Loss: 1.3493
# Epoch [9/20], Step [230/245], Loss: 1.3874
# Epoch [9/20], Step [240/245], Loss: 1.4068
# Train accuracy is: 53.375510204081635 %
# 6 Layer Network:
# Validataion accuracy is: 50.5 %
# Epoch [10/20], Step [10/245], Loss: 1.2699
# Epoch [10/20], Step [20/245], Loss: 1.3257
# Epoch [10/20], Step [30/245], Loss: 1.2923
# Epoch [10/20], Step [40/245], Loss: 1.3598
# Epoch [10/20], Step [50/245], Loss: 1.3281
# Epoch [10/20], Step [60/245], Loss: 1.2946
# Epoch [10/20], Step [70/245], Loss: 1.3419
# Epoch [10/20], Step [80/245], Loss: 1.3471
# Epoch [10/20], Step [90/245], Loss: 1.2577
# Epoch [10/20], Step [100/245], Loss: 1.3423
# Epoch [10/20], Step [110/245], Loss: 1.2389
# Epoch [10/20], Step [120/245], Loss: 1.3245
# Epoch [10/20], Step [130/245], Loss: 1.4583
# Epoch [10/20], Step [140/245], Loss: 1.1457
# Epoch [10/20], Step [150/245], Loss: 1.1634
# Epoch [10/20], Step [160/245], Loss: 1.4464
# Epoch [10/20], Step [170/245], Loss: 1.2483
# Epoch [10/20], Step [180/245], Loss: 1.3509
# Epoch [10/20], Step [190/245], Loss: 1.4294
# Epoch [10/20], Step [200/245], Loss: 1.2371
# Epoch [10/20], Step [210/245], Loss: 1.3242
# Epoch [10/20], Step [220/245], Loss: 1.3055
# Epoch [10/20], Step [230/245], Loss: 1.2251
# Epoch [10/20], Step [240/245], Loss: 1.3387
# Train accuracy is: 54.10408163265306 %
# 6 Layer Network:
# Validataion accuracy is: 50.1 %
# Epoch [11/20], Step [10/245], Loss: 1.3519
# Epoch [11/20], Step [20/245], Loss: 1.3243
# Epoch [11/20], Step [30/245], Loss: 1.2152
# Epoch [11/20], Step [40/245], Loss: 1.2207
# Epoch [11/20], Step [50/245], Loss: 1.2520
# Epoch [11/20], Step [60/245], Loss: 1.2110
# Epoch [11/20], Step [70/245], Loss: 1.3087
# Epoch [11/20], Step [80/245], Loss: 1.1860
# Epoch [11/20], Step [90/245], Loss: 1.3850
# Epoch [11/20], Step [100/245], Loss: 1.2715
# Epoch [11/20], Step [110/245], Loss: 1.3912
# Epoch [11/20], Step [120/245], Loss: 1.1929
# Epoch [11/20], Step [130/245], Loss: 1.4221
# Epoch [11/20], Step [140/245], Loss: 1.2891
# Epoch [11/20], Step [150/245], Loss: 1.3243
# Epoch [11/20], Step [160/245], Loss: 1.3240
# Epoch [11/20], Step [170/245], Loss: 1.4092
# Epoch [11/20], Step [180/245], Loss: 1.3109
# Epoch [11/20], Step [190/245], Loss: 1.3299
# Epoch [11/20], Step [200/245], Loss: 1.2200
# Epoch [11/20], Step [210/245], Loss: 1.2537
# Epoch [11/20], Step [220/245], Loss: 1.3288
# Epoch [11/20], Step [230/245], Loss: 1.3431
# Epoch [11/20], Step [240/245], Loss: 1.4959
# Train accuracy is: 54.42040816326531 %
# 6 Layer Network:
# Validataion accuracy is: 50.0 %
# Epoch [12/20], Step [10/245], Loss: 1.3140
# Epoch [12/20], Step [20/245], Loss: 1.3109
# Epoch [12/20], Step [30/245], Loss: 1.2485
# Epoch [12/20], Step [40/245], Loss: 1.2175
# Epoch [12/20], Step [50/245], Loss: 1.2329
# Epoch [12/20], Step [60/245], Loss: 1.2834
# Epoch [12/20], Step [70/245], Loss: 1.1588
# Epoch [12/20], Step [80/245], Loss: 1.3943
# Epoch [12/20], Step [90/245], Loss: 1.3222
# Epoch [12/20], Step [100/245], Loss: 1.2573
# Epoch [12/20], Step [110/245], Loss: 1.3622
# Epoch [12/20], Step [120/245], Loss: 1.3290
# Epoch [12/20], Step [130/245], Loss: 1.2277
# Epoch [12/20], Step [140/245], Loss: 1.3479
# Epoch [12/20], Step [150/245], Loss: 1.3154
# Epoch [12/20], Step [160/245], Loss: 1.2492
# Epoch [12/20], Step [170/245], Loss: 1.2728
# Epoch [12/20], Step [180/245], Loss: 1.2522
# Epoch [12/20], Step [190/245], Loss: 1.3587
# Epoch [12/20], Step [200/245], Loss: 1.2160
# Epoch [12/20], Step [210/245], Loss: 1.4969
# Epoch [12/20], Step [220/245], Loss: 1.2830
# Epoch [12/20], Step [230/245], Loss: 1.3596
# Epoch [12/20], Step [240/245], Loss: 1.3161
# Train accuracy is: 54.906122448979595 %
# 6 Layer Network:
# Validataion accuracy is: 51.6 %
# Epoch [13/20], Step [10/245], Loss: 1.2553
# Epoch [13/20], Step [20/245], Loss: 1.3791
# Epoch [13/20], Step [30/245], Loss: 1.3152
# Epoch [13/20], Step [40/245], Loss: 1.1484
# Epoch [13/20], Step [50/245], Loss: 1.1566
# Epoch [13/20], Step [60/245], Loss: 1.2326
# Epoch [13/20], Step [70/245], Loss: 1.3269
# Epoch [13/20], Step [80/245], Loss: 1.3144
# Epoch [13/20], Step [90/245], Loss: 1.2653
# Epoch [13/20], Step [100/245], Loss: 1.1478
# Epoch [13/20], Step [110/245], Loss: 1.2140
# Epoch [13/20], Step [120/245], Loss: 1.2786
# Epoch [13/20], Step [130/245], Loss: 1.1825
# Epoch [13/20], Step [140/245], Loss: 1.2495
# Epoch [13/20], Step [150/245], Loss: 1.3541
# Epoch [13/20], Step [160/245], Loss: 1.3115
# Epoch [13/20], Step [170/245], Loss: 1.3527
# Epoch [13/20], Step [180/245], Loss: 1.2978
# Epoch [13/20], Step [190/245], Loss: 1.2587
# Epoch [13/20], Step [200/245], Loss: 1.2552
# Epoch [13/20], Step [210/245], Loss: 1.2327
# Epoch [13/20], Step [220/245], Loss: 1.3208
# Epoch [13/20], Step [230/245], Loss: 1.2511
# Epoch [13/20], Step [240/245], Loss: 1.2624
# Train accuracy is: 55.3 %
# 6 Layer Network:
# Validataion accuracy is: 51.6 %
# Epoch [14/20], Step [10/245], Loss: 1.2441
# Epoch [14/20], Step [20/245], Loss: 1.2515
# Epoch [14/20], Step [30/245], Loss: 1.1500
# Epoch [14/20], Step [40/245], Loss: 1.3141
# Epoch [14/20], Step [50/245], Loss: 1.3091
# Epoch [14/20], Step [60/245], Loss: 1.2627
# Epoch [14/20], Step [70/245], Loss: 1.2424
# Epoch [14/20], Step [80/245], Loss: 1.4599
# Epoch [14/20], Step [90/245], Loss: 1.3044
# Epoch [14/20], Step [100/245], Loss: 1.3000
# Epoch [14/20], Step [110/245], Loss: 1.3045
# Epoch [14/20], Step [120/245], Loss: 1.3894
# Epoch [14/20], Step [130/245], Loss: 1.3469
# Epoch [14/20], Step [140/245], Loss: 1.1275
# Epoch [14/20], Step [150/245], Loss: 1.3021
# Epoch [14/20], Step [160/245], Loss: 1.2634
# Epoch [14/20], Step [170/245], Loss: 1.1890
# Epoch [14/20], Step [180/245], Loss: 1.1649
# Epoch [14/20], Step [190/245], Loss: 1.3207
# Epoch [14/20], Step [200/245], Loss: 1.3369
# Epoch [14/20], Step [210/245], Loss: 1.2794
# Epoch [14/20], Step [220/245], Loss: 1.2327
# Epoch [14/20], Step [230/245], Loss: 1.3515
# Epoch [14/20], Step [240/245], Loss: 1.3204
# Train accuracy is: 55.82857142857143 %
# 6 Layer Network:
# Validataion accuracy is: 51.2 %
# Epoch [15/20], Step [10/245], Loss: 1.2634
# Epoch [15/20], Step [20/245], Loss: 1.1897
# Epoch [15/20], Step [30/245], Loss: 1.3787
# Epoch [15/20], Step [40/245], Loss: 1.2252
# Epoch [15/20], Step [50/245], Loss: 1.2326
# Epoch [15/20], Step [60/245], Loss: 1.1754
# Epoch [15/20], Step [70/245], Loss: 1.3188
# Epoch [15/20], Step [80/245], Loss: 1.2466
# Epoch [15/20], Step [90/245], Loss: 1.2194
# Epoch [15/20], Step [100/245], Loss: 1.1997
# Epoch [15/20], Step [110/245], Loss: 1.2612
# Epoch [15/20], Step [120/245], Loss: 1.1862
# Epoch [15/20], Step [130/245], Loss: 1.3329
# Epoch [15/20], Step [140/245], Loss: 1.2125
# Epoch [15/20], Step [150/245], Loss: 1.2999
# Epoch [15/20], Step [160/245], Loss: 1.2569
# Epoch [15/20], Step [170/245], Loss: 1.2916
# Epoch [15/20], Step [180/245], Loss: 1.2494
# Epoch [15/20], Step [190/245], Loss: 1.2029
# Epoch [15/20], Step [200/245], Loss: 1.1113
# Epoch [15/20], Step [210/245], Loss: 1.2426
# Epoch [15/20], Step [220/245], Loss: 1.2889
# Epoch [15/20], Step [230/245], Loss: 1.1725
# Epoch [15/20], Step [240/245], Loss: 1.3050
# Train accuracy is: 56.48979591836735 %
# 6 Layer Network:
# Validataion accuracy is: 51.2 %
# Epoch [16/20], Step [10/245], Loss: 1.1816
# Epoch [16/20], Step [20/245], Loss: 1.1279
# Epoch [16/20], Step [30/245], Loss: 1.0992
# Epoch [16/20], Step [40/245], Loss: 1.2661
# Epoch [16/20], Step [50/245], Loss: 1.2254
# Epoch [16/20], Step [60/245], Loss: 1.1133
# Epoch [16/20], Step [70/245], Loss: 1.2619
# Epoch [16/20], Step [80/245], Loss: 1.2870
# Epoch [16/20], Step [90/245], Loss: 1.1443
# Epoch [16/20], Step [100/245], Loss: 1.2618
# Epoch [16/20], Step [110/245], Loss: 1.3269
# Epoch [16/20], Step [120/245], Loss: 1.2416
# Epoch [16/20], Step [130/245], Loss: 1.1989
# Epoch [16/20], Step [140/245], Loss: 1.3044
# Epoch [16/20], Step [150/245], Loss: 1.4958
# Epoch [16/20], Step [160/245], Loss: 1.2729
# Epoch [16/20], Step [170/245], Loss: 1.3974
# Epoch [16/20], Step [180/245], Loss: 1.3305
# Epoch [16/20], Step [190/245], Loss: 1.2989
# Epoch [16/20], Step [200/245], Loss: 1.3070
# Epoch [16/20], Step [210/245], Loss: 1.1456
# Epoch [16/20], Step [220/245], Loss: 1.1693
# Epoch [16/20], Step [230/245], Loss: 1.2850
# Epoch [16/20], Step [240/245], Loss: 1.2981
# Train accuracy is: 56.76734693877551 %
# 6 Layer Network:
# Validataion accuracy is: 51.1 %
# Epoch [17/20], Step [10/245], Loss: 1.2473
# Epoch [17/20], Step [20/245], Loss: 1.1310
# Epoch [17/20], Step [30/245], Loss: 1.3156
# Epoch [17/20], Step [40/245], Loss: 1.2294
# Epoch [17/20], Step [50/245], Loss: 1.3191
# Epoch [17/20], Step [60/245], Loss: 1.2089
# Epoch [17/20], Step [70/245], Loss: 1.1939
# Epoch [17/20], Step [80/245], Loss: 1.1372
# Epoch [17/20], Step [90/245], Loss: 1.1919
# Epoch [17/20], Step [100/245], Loss: 1.1678
# Epoch [17/20], Step [110/245], Loss: 1.3063
# Epoch [17/20], Step [120/245], Loss: 1.1977
# Epoch [17/20], Step [130/245], Loss: 1.3076
# Epoch [17/20], Step [140/245], Loss: 1.3804
# Epoch [17/20], Step [150/245], Loss: 1.1739
# Epoch [17/20], Step [160/245], Loss: 1.2230
# Epoch [17/20], Step [170/245], Loss: 1.2633
# Epoch [17/20], Step [180/245], Loss: 1.3430
# Epoch [17/20], Step [190/245], Loss: 1.3245
# Epoch [17/20], Step [200/245], Loss: 1.1740
# Epoch [17/20], Step [210/245], Loss: 1.1803
# Epoch [17/20], Step [220/245], Loss: 1.2078
# Epoch [17/20], Step [230/245], Loss: 1.3800
# Epoch [17/20], Step [240/245], Loss: 1.1148
# Train accuracy is: 57.23061224489796 %
# 6 Layer Network:
# Validataion accuracy is: 50.9 %
# Epoch [18/20], Step [10/245], Loss: 1.3330
# Epoch [18/20], Step [20/245], Loss: 1.3184
# Epoch [18/20], Step [30/245], Loss: 1.1826
# Epoch [18/20], Step [40/245], Loss: 1.1859
# Epoch [18/20], Step [50/245], Loss: 1.2128
# Epoch [18/20], Step [60/245], Loss: 1.1477
# Epoch [18/20], Step [70/245], Loss: 1.3416
# Epoch [18/20], Step [80/245], Loss: 1.1586
# Epoch [18/20], Step [90/245], Loss: 1.2983
# Epoch [18/20], Step [100/245], Loss: 1.2461
# Epoch [18/20], Step [110/245], Loss: 1.2439
# Epoch [18/20], Step [120/245], Loss: 1.2438
# Epoch [18/20], Step [130/245], Loss: 1.3183
# Epoch [18/20], Step [140/245], Loss: 1.2379
# Epoch [18/20], Step [150/245], Loss: 1.2315
# Epoch [18/20], Step [160/245], Loss: 1.1049
# Epoch [18/20], Step [170/245], Loss: 1.1540
# Epoch [18/20], Step [180/245], Loss: 1.2585
# Epoch [18/20], Step [190/245], Loss: 1.2241
# Epoch [18/20], Step [200/245], Loss: 1.0873
# Epoch [18/20], Step [210/245], Loss: 1.2046
# Epoch [18/20], Step [220/245], Loss: 1.2632
# Epoch [18/20], Step [230/245], Loss: 1.2350
# Epoch [18/20], Step [240/245], Loss: 1.2678
# Train accuracy is: 57.35918367346939 %
# 6 Layer Network:
# Validataion accuracy is: 50.3 %
# Epoch [19/20], Step [10/245], Loss: 1.1046
# Epoch [19/20], Step [20/245], Loss: 1.1996
# Epoch [19/20], Step [30/245], Loss: 1.3066
# Epoch [19/20], Step [40/245], Loss: 1.2402
# Epoch [19/20], Step [50/245], Loss: 1.1284
# Epoch [19/20], Step [60/245], Loss: 1.2639
# Epoch [19/20], Step [70/245], Loss: 1.2100
# Epoch [19/20], Step [80/245], Loss: 1.1148
# Epoch [19/20], Step [90/245], Loss: 1.1679
# Epoch [19/20], Step [100/245], Loss: 1.1385
# Epoch [19/20], Step [110/245], Loss: 1.1019
# Epoch [19/20], Step [120/245], Loss: 1.2168
# Epoch [19/20], Step [130/245], Loss: 1.2287
# Epoch [19/20], Step [140/245], Loss: 1.1520
# Epoch [19/20], Step [150/245], Loss: 1.2560
# Epoch [19/20], Step [160/245], Loss: 1.2631
# Epoch [19/20], Step [170/245], Loss: 1.1836
# Epoch [19/20], Step [180/245], Loss: 1.1945
# Epoch [19/20], Step [190/245], Loss: 1.1237
# Epoch [19/20], Step [200/245], Loss: 1.2564
# Epoch [19/20], Step [210/245], Loss: 1.2244
# Epoch [19/20], Step [220/245], Loss: 1.3201
# Epoch [19/20], Step [230/245], Loss: 1.2942
# Epoch [19/20], Step [240/245], Loss: 1.1993
# Train accuracy is: 57.78367346938776 %
# 6 Layer Network:
# Validataion accuracy is: 51.5 %
# Epoch [20/20], Step [10/245], Loss: 1.2297
# Epoch [20/20], Step [20/245], Loss: 1.1353
# Epoch [20/20], Step [30/245], Loss: 1.2267
# Epoch [20/20], Step [40/245], Loss: 1.2926
# Epoch [20/20], Step [50/245], Loss: 1.2784
# Epoch [20/20], Step [60/245], Loss: 1.2449
# Epoch [20/20], Step [70/245], Loss: 1.2525
# Epoch [20/20], Step [80/245], Loss: 1.1311
# Epoch [20/20], Step [90/245], Loss: 1.0895
# Epoch [20/20], Step [100/245], Loss: 1.1837
# Epoch [20/20], Step [110/245], Loss: 1.0811
# Epoch [20/20], Step [120/245], Loss: 1.0675
# Epoch [20/20], Step [130/245], Loss: 1.2176
# Epoch [20/20], Step [140/245], Loss: 1.2200
# Epoch [20/20], Step [150/245], Loss: 1.1609
# Epoch [20/20], Step [160/245], Loss: 1.1560
# Epoch [20/20], Step [170/245], Loss: 1.1508
# Epoch [20/20], Step [180/245], Loss: 1.1166
# Epoch [20/20], Step [190/245], Loss: 1.1608
# Epoch [20/20], Step [200/245], Loss: 1.2486
# Epoch [20/20], Step [210/245], Loss: 1.3438
# Epoch [20/20], Step [220/245], Loss: 1.2806
# Epoch [20/20], Step [230/245], Loss: 1.0505
# Epoch [20/20], Step [240/245], Loss: 1.1641
# Train accuracy is: 57.755102040816325 %
# 6 Layer Network:
# Validataion accuracy is: 50.9 %
# Final validation accuracy for different layers [52.5, 50.5, 52.3, 51.0, 50.9]
# Final validation accuracy for  2  layer network is:  52.5
# Final validation accuracy for  3  layer network is:  50.5
# Final validation accuracy for  4  layer network is:  52.3
# Final validation accuracy for  5  layer network is:  51.0
# Final validation accuracy for  6  layer network is:  50.9
# Best model is: 2 layer network
# Accuracy of the network on the 1000 test images: 51.1 %

# %% [markdown]
# Initially the Multilayerperceptron is created generically such that depending on the inputs, different layers network are initialisied.
#
# For the 2 layer network, we achieved validation accuracy of 51.5%. which is above 48%.
#
# Experimenting with different number of layers:
#     The whole training and validation code is run in a loop for different number of layers. We checked from 2 to 6 layers.
#     We also experimented with dropout layers when the number of layers are 4 and 5.
#     When the number of layers is 3, we got the final validation accuracy of 51.2%, but we can see that when the number of epoch is 18,
#     the validation accuracy is of 52.2% and then it decreased. This may be because of overfitting of the data and weights are adjusted
#     according to that and in the next epoch is decreased. Similarly for other layers. Adding extra layers slightly quickly converges
#     the model in less number of epochs and increases the validation accuracies, but should be careful with overfitting.
#
#     Final validation  accuracies:
#         Final validation accuracy for  2  layer network is:  51.5
#         Final validation accuracy for  3  layer network is:  51.2
#         Final validation accuracy for  4  layer network is:  52.3
#         Final validation accuracy for  5  layer network is:  51.0
#         Final validation accuracy for  6  layer network is:  52.0
#
#     Then we saved all the models and whichever has highest final validation accuracy is chosen as the best model and used for
#     test data.
#         Best model is: 4 layer network
